# %%
# !pip install mesa[rec]
# !pip install seaborn

# Has multi-dimensional arrays and matrices.
# Has a large collection of mathematical functions to operate on these arrays.
import numpy as np

# Data manipulation and analysis.
import pandas as pd

# Data visualization tools.
import seaborn as sns

import mesa

import random
# Out:
# Collecting mesa[rec]
#   Downloading mesa-3.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (1.15.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (4.67.1)
# Requirement already satisfied: altair in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (5.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (3.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (3.4.2)
# Collecting solara (from mesa[rec])
#   Downloading solara-1.47.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (1.40.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (4.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->mesa[rec]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->mesa[rec]) (2025.2)
# Collecting solara-server==1.47.0 (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading solara_server-1.47.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting solara-ui==1.47.0 (from solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading solara_ui-1.47.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: click>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (8.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (3.18.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (6.17.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.11/dist-packages (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (6.1.12)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (5.10.4)
# Collecting rich-click (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading rich_click-1.8.9-py3-none-any.whl.metadata (7.9 kB)
# Collecting watchdog (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.2 MB/s eta 0:00:00
# Collecting watchfiles (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting starlette (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting uvicorn (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: websockets in /usr/local/lib/python3.11/dist-packages (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (15.0.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (4.12.3)
# Collecting ipyvue>=1.9.0 (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading ipyvue-1.11.2-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting ipyvuetify>=1.6.10 (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading ipyvuetify-1.11.1-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets>=7.7 in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (7.7.1)
# Collecting reacton>=1.9 (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading reacton-1.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (2.32.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.47.0->solara->mesa[rec]) (5.5.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.47.0->solara->mesa[rec]) (3.8)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.47.0->solara->mesa[rec]) (2.19.1)
# Collecting pymdown-extensions (from solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading pymdown_extensions-10.15-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (0.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mesa[rec]) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair->mesa[rec]) (3.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.0.15)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (6.4.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (5.7.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (2.21.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from pymdown-extensions->solara-ui[all]==1.47.0->solara->mesa[rec]) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (2025.4.26)
# Requirement already satisfied: rich>=10.7 in /usr/local/lib/python3.11/dist-packages (from rich-click->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (13.9.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (4.9.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (1.3.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (4.3.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.7->rich-click->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (3.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (0.1.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (23.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.22.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.2.13)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (2.22)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.8.0)
# Downloading mesa-3.2.0-py3-none-any.whl (197 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.0/197.0 kB 9.1 MB/s eta 0:00:00
# Downloading solara-1.47.0-py3-none-any.whl (5.9 kB)
# Downloading solara_server-1.47.0-py3-none-any.whl (3.9 kB)
# Downloading solara_ui-1.47.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.8 MB/s eta 0:00:00
# Downloading ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 60.5 MB/s eta 0:00:00
# Downloading ipyvuetify-1.11.1-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 32.1 MB/s eta 0:00:00
# Downloading reacton-1.9.1-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 8.0 MB/s eta 0:00:00
# Downloading pymdown_extensions-10.15-py3-none-any.whl (265 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.8/265.8 kB 15.4 MB/s eta 0:00:00
# Downloading rich_click-1.8.9-py3-none-any.whl (36 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.4 MB/s eta 0:00:00
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 4.8 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.8 MB/s eta 0:00:00
# Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 28.0 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.6 MB/s eta 0:00:00
# Installing collected packages: watchdog, uvicorn, pymdown-extensions, jedi, watchfiles, starlette, rich-click, mesa, reacton, ipyvue, ipyvuetify, solara-ui, solara-server, solara
# Successfully installed ipyvue-1.11.2 ipyvuetify-1.11.1 jedi-0.19.2 mesa-3.2.0 pymdown-extensions-10.15 reacton-1.9.1 rich-click-1.8.9 solara-1.47.0 solara-server-1.47.0 solara-ui-1.47.0 starlette-0.46.2 uvicorn-0.34.2 watchdog-6.0.0 watchfiles-1.0.5
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import random

# === FUNDAMENTAL AGENT STRATEGIES ===
def fundamental_strategy_0(agent, model):
    """Basit Değer Stratejisi: Fiyat < Temel Değerse al."""
    #print(f"Fundamental_strategy_0 aktif")
    if model.price < model.fundamental_value_0:
        return "buy"
    elif model.price > model.fundamental_value_0:
        return "sell"
    return "hold"

def fundamental_strategy_1(agent, model):
    """Basit Değer Stratejisi: Fiyat < Temel Değerse al."""
    #print(f"Fundamental_strategy_1 aktif")
    if model.price < model.fundamental_value_1:
        return "buy"
    elif model.price > model.fundamental_value_1:
        return "sell"
    return "hold"

def fundamental_strategy_2(agent, model):
    """Trend Takip (Fundamental bazlı): Temel değer artıyorsa al."""
    #print(f"Fundamental_strategy_2 aktif")
    if model.fundamental_value_2 > model.prev_fundamental_value_2:
        return "buy"
    elif model.fundamental_value_2 < model.prev_fundamental_value_2:
        return "sell"
    return "hold"

def fundamental_strategy_3(agent, model):
    """Asimetrik Temel Değere Göre al-sat-bekle"""
    #print(f"Fundamental_strategy_3 aktif")
    if model.price < model.fundamental_value_3:
        return "buy"
    elif model.price > model.fundamental_value_3:
        return "sell"
    return "hold"




fundamental_strategies = [
    fundamental_strategy_0,
    fundamental_strategy_1,
    fundamental_strategy_2,
    fundamental_strategy_3
]

# === TECHNICAL AGENT STRATEGIES ===
def technical_strategy_0(agent, model):
    """Basit Momentum: Fiyat yükseliyorsa al."""
    if model.price > model.prev_price:
        return "buy"
    elif model.price < model.prev_price:
        return "sell"
    return "hold"

def technical_strategy_1(agent, model):
    """Tersine Tepki: Fiyat düşüyorsa al."""
    if model.price < model.prev_price:
        return "buy"
    elif model.price > model.prev_price:
        return "sell"
    return "hold"

def technical_strategy_2(agent, model):
    """Rastgele Momentum: %60 ihtimalle trend takibi"""
    if random.random() < 0.6:
        return technical_strategy_0(agent, model)
    else:
        return "hold"

def technical_strategy_3(agent, model):
    """Trend Dönüşü: Son üç fiyatı analiz et."""
    history = model.price_history
    if len(history) >= 3:
        if history[-1] > history[-2] > history[-3]:
            return "sell"
        elif history[-1] < history[-2] < history[-3]:
            return "buy"
    return "hold"

technical_strategies = [
    technical_strategy_0,
    technical_strategy_1,
    technical_strategy_2,
    technical_strategy_3
]

# === NOISE AGENT STRATEGIES ===
def noise_strategy_0(agent, model):
    """Rastgele işlem."""
    return random.choice(["buy", "sell", "hold"])

def noise_strategy_1(agent, model):
    """Daha çok hold eğilimli rastgele işlem."""
    return random.choices(["buy", "sell", "hold"], weights=[0.2, 0.2, 0.6])[0]

def noise_strategy_2(agent, model):
    """Fiyatın çift/tek olmasına göre karar verir."""
    if int(model.price) % 2 == 0:
        return "buy"
    else:
        return "sell"

def noise_strategy_3(agent, model):
    """Rastgele ancak varlığı olanlar daha çok satar."""
    if agent.asset > 0 and random.random() < 0.6:
        return "sell"
    return random.choice(["buy", "hold"])

noise_strategies = [
    noise_strategy_0,
    noise_strategy_1,
    noise_strategy_2,
    noise_strategy_3
]

# %%
class BaseAgent(mesa.Agent):
    def __init__(self, model, agent_type, strategy_id):
        super().__init__(model)
        self.agent_type = agent_type  # 'fundamental', 'technical', 'noise'
        self.strategy_id = strategy_id  # 0, 1, 2, 3 (her tür için 4 strateji)
        self.cash = 1000.0
        self.asset = 0
        self.last_action = None  # 'buy', 'sell', 'hold'

    def step(self):
        raise NotImplementedError("This method should be implemented by subclasses.")


class FundamentalAgent(BaseAgent):
    def __init__(self, model, strategy_id):
        super().__init__(model, "fundamental", strategy_id)

    def step(self):
        #from strategies import fundamental_strategies
        action = fundamental_strategies[self.strategy_id](self, self.model)
        self.execute_action(action)

    def execute_action(self, action):
        price = self.model.price
        if action == "buy" and self.cash >= price:
            self.asset += 1
            self.cash -= price
            self.model.total_demand += 1
        elif action == "sell" and self.asset > 0:
            self.asset -= 1
            self.cash += price
            self.model.total_supply += 1
        self.last_action = action


class TechnicalAgent(BaseAgent):
    def __init__(self, model, strategy_id):
        super().__init__(model, "technical", strategy_id)

    def step(self):
        #from strategies import technical_strategies
        action = technical_strategies[self.strategy_id](self, self.model)
        self.execute_action(action)

    def execute_action(self, action):
        price = self.model.price
        if action == "buy" and self.cash >= price:
            self.asset += 1
            self.cash -= price
            self.model.total_demand += 1
        elif action == "sell" and self.asset > 0:
            self.asset -= 1
            self.cash += price
            self.model.total_supply += 1
        self.last_action = action


class NoiseAgent(BaseAgent):
    def __init__(self, model, strategy_id):
        super().__init__(model, "noise", strategy_id)

    def step(self):
        #from strategies import noise_strategies
        action = noise_strategies[self.strategy_id](self, self.model)
        self.execute_action(action)

    def execute_action(self, action):
        price = self.model.price
        if action == "buy" and self.cash >= price:
            self.asset += 1
            self.cash -= price
            self.model.total_demand += 1
        elif action == "sell" and self.asset > 0:
            self.asset -= 1
            self.cash += price
            self.model.total_supply += 1
        self.last_action = action

# %%
from mesa.datacollection import DataCollector
#from agents import FundamentalAgent, TechnicalAgent, NoiseAgent
#from strategies import fundamental_strategies, technical_strategies, noise_strategies
import random

class MarketModel(mesa.Model):
    def __init__(self,
                 num_fundamental=400,
                 num_technical=400,
                 num_noise=400,
                 initial_price=100,
                 initial_fundamental_value=100):
        super().__init__()

        # Initialize total_demand and total_supply attributes
        self.total_demand = 0
        self.total_supply = 0


        self.price = initial_price
        self.prev_price = initial_price
        self.fundamental_value_0= initial_fundamental_value
        self.fundamental_value_1 = initial_fundamental_value
        self.fundamental_value_2 = initial_fundamental_value
        self.fundamental_value_3 = initial_fundamental_value


        self.prev_fundamental_value_0= initial_fundamental_value
        self.prev_fundamental_value_1 = initial_fundamental_value
        self.prev_fundamental_value_2 = initial_fundamental_value
        self.prev_fundamental_value_3 = initial_fundamental_value

        self.price_history = [initial_price]
        self.fundamental_history_0 = [initial_fundamental_value]
        self.fundamental_history_1 = [initial_fundamental_value]
        self.fundamental_history_2 = [initial_fundamental_value]
        self.fundamental_history_3 = [initial_fundamental_value]

        self.step_count = 0


        self.news = 0
        self.news_history = []
        # Haber dağılımı
        self.news_values = [-2, -1, 0, 1, 2]
        self.news_probs = [0.05, 0.20, 0.50, 0.20, 0.05]





        # Ajanları oluştur
        # Fundamental agents
        for i in range(num_fundamental):
            strat_index = i % 4
            agent = FundamentalAgent(self, strat_index)
            self.agents.add(agent)

        # Technical agents
        for i in range(num_technical):
            strat_index = i % 4
            agent = TechnicalAgent(self, strat_index)
            self.agents.add(agent)

        # Noise agents
        for i in range(num_noise):
            strat_index = i % 4
            agent = NoiseAgent(self, strat_index)
            self.agents.add(agent)

        # DataCollector'ı tüm fundamental_value'ları içerecek şekilde güncelle
        self.datacollector = DataCollector(
            model_reporters={
                "Price": lambda m: m.price,
                "FundamentalValue_0": lambda m: m.fundamental_value_0,
                "FundamentalValue_1": lambda m: m.fundamental_value_1,
                "FundamentalValue_2": lambda m: m.fundamental_value_2,
                "FundamentalValue_3": lambda m: m.fundamental_value_3
            }
        )

    def update_fundamental_value_0(self):
        # Sabit etki
        if self.news > 0:
            score_news_0 = self.news * 0.1 # pozitif haber
        elif self.news < 0:
            score_news_0 = self.news * 0.1 # negatif haber. pozitif haber ile aynı tepki
        else:
            score_news_0 = self.news # yeni haber yok

        print(f"Haber/Bilgi_0: {score_news_0}")
        self.prev_fundamental_value_0= self.fundamental_value_0
        self.fundamental_value_0 += self.fundamental_value_0 * score_news_0
        self.fundamental_history_0.append(self.fundamental_value_0)


    def update_fundamental_value_1(self):
        # Asimetrik Etki
        if self.news > 0:
            score_news_1 = self.news * 0.1 # pozitif haber
        elif self.news < 0:
            score_news_1 = self.news * 0.15 # negatif haber. pozitif haberden daha fazla duyarlılık
        else:
            score_news_1 = self.news # yeni haber yok

        print(f"Haber/Bilgi_1: {score_news_1}")
        self.prev_fundamental_value_1 = self.fundamental_value_1
        self.fundamental_value_1 += self.fundamental_value_1 * score_news_1
        self.fundamental_history_1.append(self.fundamental_value_1)

    def update_fundamental_value_2(self):
        # Güçlenen Etki
        score_news_2 = 0
        score_news_2 = self.news * 0.1 + score_news_2


        print(f"Haber/Bilgi_2: {score_news_2}")
        self.prev_fundamental_value_2 = self.fundamental_value_2
        self.fundamental_value_2 += self.fundamental_value_2 * score_news_2
        self.fundamental_history_2.append(self.fundamental_value_2)


    def update_fundamental_value_3(self):
        # Sönümlü Etki
        lam = 0.8
        num_history_steps = 5
        score_news_3 = 0

        # Haber geçmişinden son N adımı al (N=num_history_steps)
        # news_history listesi self.step metodunda dolduruluyor.
        # len(self.news_history) modelin çalıştığı adım sayısıdır.
        # İlk adımlarda len(self.news_history) 5'ten küçük olacaktır.
        # Sadece mevcut olan geçmiş adımları kullan.

        # Geçmişten alınacak adım sayısı, haber geçmişinin uzunluğu ve istenen maksimum adım sayısı arasındaki minimum değerdir.
        steps_to_consider = min(len(self.news_history), num_history_steps)

        # En güncel haberden başlayarak (yani en sondan) geriye doğru döngü yap
        # news_history[-steps_to_consider:] son 'steps_to_consider' elemanı verir.
        # reversed() ile bunu tersten okuyarak en güncel haberi (indeks 0) ilk işleriz.
        recent_news = self.news_history[-steps_to_consider:]

        for i, news_val in enumerate(reversed(recent_news)):
             score_news_3 += news_val * (lam ** i)

        score_news_3 *= 0.1 # Ölçeklendirme faktörü


        # print(f"Haber/Bilgi_3: score_{score_news_3}") # Debugging çıktısı kaldırıldı
        self.prev_fundamental_value_3 = self.fundamental_value_3
        self.fundamental_value_3 += self.fundamental_value_3 * score_news_3
        self.fundamental_history_3.append(self.fundamental_value_3)

    def update_price(self, demand, supply):
        #Fiyatı arz-talep farkına göre günceller.
        imbalance = demand - supply
        self.prev_price = self.price
        self.price += 0.1 * imbalance  # Duyarlılık katsayısı
        self.price = max(1, self.price)  # Negatif fiyatı engelle
        self.price_history.append(self.price)

    def step(self):
        """Zaman adımını ilerletir."""
        self.step_count += 1


        self.total_demand = 0
        self.total_supply = 0

        self.news = np.random.choice(self.news_values, p=self.news_probs)
        self.news_history.append(self.news)


        # Agent step method calls execute_action which updates model's total_demand/supply
        self.agents.do("step")


        self.update_fundamental_value_0()
        self.update_fundamental_value_1()
        self.update_fundamental_value_2()
        self.update_fundamental_value_3()


        # Fiyat güncelle
        self.update_price(self.total_demand, self.total_supply)

        # Print price after update
        print(f"Step {self.step_count}: New Price = {self.price}")


        # Print demand and supply before price update
        print(f"Step {self.step_count}: Demand = {self.total_demand}, Supply = {self.total_supply}")




        # Veri topla
        self.datacollector.collect(self)

    def run_model(self, steps=100):
        for _ in range(steps):
            self.step()

# %%
import matplotlib.pyplot as plt

# Sadece temel ajanlarla simülasyon
model = MarketModel(num_fundamental=400, num_technical=0, num_noise=0)
model.run_model(steps=100)

# Fiyatları çiz
price_history = model.price_history
plt.figure(figsize=(10, 4))
plt.plot(price_history, label="Fiyat")
plt.title("Zamanla Fiyat Değişimi (Sadece Temel Ajanlar)")
plt.xlabel("Zaman")
plt.ylabel("Fiyat")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 1: New Price = 100.0
# Step 1: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 2: New Price = 140.0
# Step 2: Demand = 400, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 3: New Price = 140.0
# Step 3: Demand = 200, Supply = 200
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 4: New Price = 140.0
# Step 4: Demand = 100, Supply = 100
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 5: New Price = 140.0
# Step 5: Demand = 100, Supply = 100
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 6: New Price = 160.0
# Step 6: Demand = 200, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 7: New Price = 160.0
# Step 7: Demand = 100, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 8: New Price = 150.0
# Step 8: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 9: New Price = 140.0
# Step 9: Demand = 0, Supply = 100
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 10: New Price = 160.0
# Step 10: Demand = 200, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 11: New Price = 140.0
# Step 11: Demand = 0, Supply = 200
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 12: New Price = 160.0
# Step 12: Demand = 200, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 13: New Price = 180.0
# Step 13: Demand = 200, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 14: New Price = 190.0
# Step 14: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 15: New Price = 190.0
# Step 15: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 16: New Price = 180.0
# Step 16: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 17: New Price = 170.0
# Step 17: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 18: New Price = 160.0
# Step 18: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 19: New Price = 180.0
# Step 19: Demand = 200, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 20: New Price = 190.0
# Step 20: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 21: New Price = 190.0
# Step 21: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 22: New Price = 190.0
# Step 22: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 23: New Price = 190.0
# Step 23: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 24: New Price = 180.0
# Step 24: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 25: New Price = 180.0
# Step 25: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 26: New Price = 180.0
# Step 26: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 27: New Price = 190.0
# Step 27: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 28: New Price = 190.0
# Step 28: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 29: New Price = 180.0
# Step 29: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 30: New Price = 180.0
# Step 30: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 31: New Price = 190.0
# Step 31: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 32: New Price = 190.0
# Step 32: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 33: New Price = 180.0
# Step 33: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 34: New Price = 190.0
# Step 34: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 35: New Price = 190.0
# Step 35: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 36: New Price = 190.0
# Step 36: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 37: New Price = 190.0
# Step 37: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 38: New Price = 180.0
# Step 38: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 39: New Price = 170.0
# Step 39: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 40: New Price = 170.0
# Step 40: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 41: New Price = 170.0
# Step 41: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 42: New Price = 180.0
# Step 42: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 43: New Price = 190.0
# Step 43: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 44: New Price = 180.0
# Step 44: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 45: New Price = 180.0
# Step 45: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 46: New Price = 190.0
# Step 46: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 47: New Price = 190.0
# Step 47: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 48: New Price = 190.0
# Step 48: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 49: New Price = 200.0
# Step 49: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 50: New Price = 200.0
# Step 50: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 51: New Price = 200.0
# Step 51: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 52: New Price = 200.0
# Step 52: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 53: New Price = 210.0
# Step 53: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 54: New Price = 200.0
# Step 54: Demand = 0, Supply = 100
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 55: New Price = 210.0
# Step 55: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 56: New Price = 200.0
# Step 56: Demand = 0, Supply = 100
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 57: New Price = 200.0
# Step 57: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 58: New Price = 190.0
# Step 58: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 59: New Price = 180.0
# Step 59: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 60: New Price = 190.0
# Step 60: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 61: New Price = 190.0
# Step 61: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 62: New Price = 190.0
# Step 62: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 63: New Price = 190.0
# Step 63: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 64: New Price = 190.0
# Step 64: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 65: New Price = 190.0
# Step 65: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 66: New Price = 190.0
# Step 66: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 67: New Price = 200.0
# Step 67: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 68: New Price = 210.0
# Step 68: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 69: New Price = 220.0
# Step 69: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 70: New Price = 210.0
# Step 70: Demand = 0, Supply = 100
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 71: New Price = 210.0
# Step 71: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 72: New Price = 200.0
# Step 72: Demand = 0, Supply = 100
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 73: New Price = 200.0
# Step 73: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 74: New Price = 190.0
# Step 74: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 75: New Price = 190.0
# Step 75: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 76: New Price = 200.0
# Step 76: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 77: New Price = 200.0
# Step 77: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 78: New Price = 200.0
# Step 78: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 79: New Price = 210.0
# Step 79: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 80: New Price = 210.0
# Step 80: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 81: New Price = 210.0
# Step 81: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 82: New Price = 210.0
# Step 82: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 83: New Price = 210.0
# Step 83: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 84: New Price = 210.0
# Step 84: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 85: New Price = 200.0
# Step 85: Demand = 0, Supply = 100
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 86: New Price = 200.0
# Step 86: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 87: New Price = 190.0
# Step 87: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 88: New Price = 200.0
# Step 88: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 89: New Price = 200.0
# Step 89: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 90: New Price = 200.0
# Step 90: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 91: New Price = 190.0
# Step 91: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 92: New Price = 190.0
# Step 92: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 93: New Price = 190.0
# Step 93: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 94: New Price = 190.0
# Step 94: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 95: New Price = 190.0
# Step 95: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 96: New Price = 190.0
# Step 96: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 97: New Price = 200.0
# Step 97: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 98: New Price = 200.0
# Step 98: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 99: New Price = 190.0
# Step 99: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 100: New Price = 200.0
# Step 100: Demand = 100, Supply = 0

# %%
import matplotlib.pyplot as plt
# MarketModel sınıfınızın tanımlandığından emin olun (önceki hücreyi çalıştırarak)
# Agent ve strategy tanımlarının da yapıldığından emin olun

# Sadece temel ajanlarla simülasyon
# Daha önce düzeltilen MarketModel sınıfını kullanın
model = MarketModel(num_fundamental=400, num_technical=0, num_noise=0)
model.run_model(steps=1000)

# Fiyatları ve Temel Değeri çiz
price_history = model.price_history
fundamental_history_0= model.fundamental_history_0 # Temel değer geçmişini al
fundamental_history_1= model.fundamental_history_1 # Temel değer geçmişini al
fundamental_history_2= model.fundamental_history_2 # Temel değer geçmişini al
fundamental_history_3= model.fundamental_history_3 # Temel değer geçmişini al




plt.figure(figsize=(12, 6)) # Grafik boyutunu büyütelim
plt.plot(price_history, label="Fiyat", color='blue')
plt.plot(fundamental_history_0, label="Temel Değer 0", color='red', linestyle='--') # Temel değeri kesikli çizgiyle ekle
plt.plot(fundamental_history_1, label="Temel Değer 1", color='green', linestyle='--') # Temel değeri kesikli çizgiyle ekle
plt.plot(fundamental_history_2, label="Temel Değer 2", color='orange', linestyle='--') # Temel değeri kesikli çizgiyle ekle
plt.plot(fundamental_history_3, label="Temel Değer 3", color='purple', linestyle='--') # Temel değeri kesikli çizgiyle ekle



plt.title("Zamanla Fiyat ve Temel Değer Değişimi (Sadece Temel Ajanlar)")
plt.xlabel("Zaman Adımı")
plt.ylabel("Değer")
plt.grid(True)
plt.legend()
plt.tight_layout() # Grafik düzenlemesini otomatik ayarla
plt.show()
# Out:
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 1: New Price = 100.0
# Step 1: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 2: New Price = 100.0
# Step 2: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 3: New Price = 100.0
# Step 3: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 4: New Price = 100.0
# Step 4: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 5: New Price = 100.0
# Step 5: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 6: New Price = 110.0
# Step 6: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 7: New Price = 110.0
# Step 7: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 8: New Price = 110.0
# Step 8: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 9: New Price = 110.0
# Step 9: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 10: New Price = 120.0
# Step 10: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 11: New Price = 120.0
# Step 11: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 12: New Price = 130.0
# Step 12: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 13: New Price = 150.0
# Step 13: Demand = 200, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 14: New Price = 130.0
# Step 14: Demand = 0, Supply = 200
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 15: New Price = 140.0
# Step 15: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 16: New Price = 120.0
# Step 16: Demand = 0, Supply = 200
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 17: New Price = 110.0
# Step 17: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 18: New Price = 110.0
# Step 18: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 19: New Price = 110.0
# Step 19: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 20: New Price = 110.0
# Step 20: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 21: New Price = 110.0
# Step 21: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 22: New Price = 100.0
# Step 22: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 23: New Price = 110.0
# Step 23: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 24: New Price = 110.0
# Step 24: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 25: New Price = 110.0
# Step 25: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 26: New Price = 110.0
# Step 26: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 27: New Price = 100.0
# Step 27: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 28: New Price = 110.0
# Step 28: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 29: New Price = 110.0
# Step 29: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 30: New Price = 110.0
# Step 30: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 31: New Price = 100.0
# Step 31: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 32: New Price = 100.0
# Step 32: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 33: New Price = 100.0
# Step 33: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 34: New Price = 110.0
# Step 34: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 35: New Price = 120.0
# Step 35: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 36: New Price = 110.0
# Step 36: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 37: New Price = 110.0
# Step 37: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 38: New Price = 110.0
# Step 38: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 39: New Price = 110.0
# Step 39: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 40: New Price = 110.0
# Step 40: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 41: New Price = 110.0
# Step 41: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 42: New Price = 110.0
# Step 42: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 43: New Price = 120.0
# Step 43: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 44: New Price = 110.0
# Step 44: Demand = 0, Supply = 100
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 45: New Price = 110.0
# Step 45: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 46: New Price = 100.0
# Step 46: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 47: New Price = 110.0
# Step 47: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 48: New Price = 110.0
# Step 48: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 49: New Price = 110.0
# Step 49: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 50: New Price = 110.0
# Step 50: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 51: New Price = 100.0
# Step 51: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 52: New Price = 100.0
# Step 52: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 53: New Price = 100.0
# Step 53: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 54: New Price = 100.0
# Step 54: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 55: New Price = 100.0
# Step 55: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 56: New Price = 100.0
# Step 56: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 57: New Price = 100.0
# Step 57: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 58: New Price = 100.0
# Step 58: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 59: New Price = 100.0
# Step 59: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 60: New Price = 100.0
# Step 60: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 61: New Price = 100.0
# Step 61: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 62: New Price = 100.0
# Step 62: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 63: New Price = 100.0
# Step 63: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 64: New Price = 100.0
# Step 64: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 65: New Price = 100.0
# Step 65: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 66: New Price = 100.0
# Step 66: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 67: New Price = 100.0
# Step 67: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 68: New Price = 100.0
# Step 68: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 69: New Price = 100.0
# Step 69: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 70: New Price = 100.0
# Step 70: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 71: New Price = 110.0
# Step 71: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 72: New Price = 120.0
# Step 72: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 73: New Price = 120.0
# Step 73: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 74: New Price = 120.0
# Step 74: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 75: New Price = 120.0
# Step 75: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 76: New Price = 120.0
# Step 76: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 77: New Price = 120.0
# Step 77: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 78: New Price = 120.0
# Step 78: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 79: New Price = 120.0
# Step 79: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 80: New Price = 120.0
# Step 80: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 81: New Price = 130.0
# Step 81: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 82: New Price = 120.0
# Step 82: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 83: New Price = 130.0
# Step 83: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 84: New Price = 130.0
# Step 84: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.2
# Haber/Bilgi_1: -0.3
# Haber/Bilgi_2: -0.2
# Step 85: New Price = 130.0
# Step 85: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 86: New Price = 120.0
# Step 86: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 87: New Price = 120.0
# Step 87: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 88: New Price = 120.0
# Step 88: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 89: New Price = 110.0
# Step 89: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 90: New Price = 100.0
# Step 90: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 91: New Price = 100.0
# Step 91: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 92: New Price = 100.0
# Step 92: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 93: New Price = 100.0
# Step 93: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 94: New Price = 100.0
# Step 94: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.2
# Haber/Bilgi_1: -0.3
# Haber/Bilgi_2: -0.2
# Step 95: New Price = 110.0
# Step 95: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 96: New Price = 100.0
# Step 96: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 97: New Price = 100.0
# Step 97: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 98: New Price = 110.0
# Step 98: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 99: New Price = 100.0
# Step 99: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 100: New Price = 100.0
# Step 100: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 101: New Price = 100.0
# Step 101: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.2
# Haber/Bilgi_1: -0.3
# Haber/Bilgi_2: -0.2
# Step 102: New Price = 100.0
# Step 102: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 103: New Price = 100.0
# Step 103: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 104: New Price = 100.0
# Step 104: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 105: New Price = 100.0
# Step 105: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 106: New Price = 100.0
# Step 106: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 107: New Price = 100.0
# Step 107: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 108: New Price = 100.0
# Step 108: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 109: New Price = 100.0
# Step 109: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 110: New Price = 100.0
# Step 110: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 111: New Price = 100.0
# Step 111: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 112: New Price = 100.0
# Step 112: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 113: New Price = 100.0
# Step 113: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 114: New Price = 100.0
# Step 114: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 115: New Price = 100.0
# Step 115: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 116: New Price = 100.0
# Step 116: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.2
# Haber/Bilgi_1: -0.3
# Haber/Bilgi_2: -0.2
# Step 117: New Price = 100.0
# Step 117: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 118: New Price = 100.0
# Step 118: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 119: New Price = 100.0
# Step 119: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 120: New Price = 100.0
# Step 120: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 121: New Price = 110.0
# Step 121: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 122: New Price = 100.0
# Step 122: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 123: New Price = 100.0
# Step 123: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 124: New Price = 100.0
# Step 124: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 125: New Price = 110.0
# Step 125: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 126: New Price = 110.0
# Step 126: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 127: New Price = 100.0
# Step 127: Demand = 0, Supply = 100
# Haber/Bilgi_0: -0.2
# Haber/Bilgi_1: -0.3
# Haber/Bilgi_2: -0.2
# Step 128: New Price = 110.0
# Step 128: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 129: New Price = 100.0
# Step 129: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 130: New Price = 100.0
# Step 130: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 131: New Price = 100.0
# Step 131: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 132: New Price = 100.0
# Step 132: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 133: New Price = 100.0
# Step 133: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 134: New Price = 100.0
# Step 134: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 135: New Price = 110.0
# Step 135: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 136: New Price = 110.0
# Step 136: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 137: New Price = 120.0
# Step 137: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 138: New Price = 110.0
# Step 138: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step
Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 1000: New Price = 270.0
# Step 1000: Demand = 0, Supply = 0

# %%
import matplotlib.pyplot as plt
import pandas as pd
from mesa.datacollection import DataCollector
import random
import numpy as np # numpy'nin import edildiğinden emin ol

class MarketModel(mesa.Model):
    def __init__(self,
                 num_fundamental=400,
                 num_technical=400,
                 num_noise=400,
                 initial_price=100,
                 initial_fundamental_value=100):
        super().__init__()

        # Initialize total_demand and total_supply attributes
        self.total_demand = 0
        self.total_supply = 0


        self.price = initial_price
        self.prev_price = initial_price
        self.fundamental_value_0= initial_fundamental_value
        self.fundamental_value_1 = initial_fundamental_value
        self.fundamental_value_2 = initial_fundamental_value
        self.fundamental_value_3 = initial_fundamental_value


        self.prev_fundamental_value_0= initial_fundamental_value
        self.prev_fundamental_value_1 = initial_fundamental_value
        self.prev_fundamental_value_2 = initial_fundamental_value
        self.prev_fundamental_value_3 = initial_fundamental_value

        self.price_history = [initial_price]
        self.fundamental_history_0 = [initial_fundamental_value]
        self.fundamental_history_1 = [initial_fundamental_value]
        self.fundamental_history_2 = [initial_fundamental_value]
        self.fundamental_history_3 = [initial_fundamental_value]

        self.step_count = 0

        # self.news yerine news geçmişini tut
        self.news_history = []
        # Haber dağılımı
        self.news_values = [-2, -1, 0, 1, 2]
        self.news_probs = [0.05, 0.20, 0.50, 0.20, 0.05]





        # Ajanları oluştur
        # Fundamental agents
        for i in range(num_fundamental):
            strat_index = i % 4
            agent = FundamentalAgent(self, strat_index)
            self.agents.add(agent)

        # Technical agents
        for i in range(num_technical):
            strat_index = i % 4
            agent = TechnicalAgent(self, strat_index)
            self.agents.add(agent)

        # Noise agents
        for i in range(num_noise):
            strat_index = i % 4
            agent = NoiseAgent(self, strat_index)
            self.agents.add(agent)

        # DataCollector'ı tüm fundamental_value'ları içerecek şekilde güncelle
        self.datacollector = DataCollector(
            model_reporters={
                "Price": lambda m: m.price,
                "FundamentalValue_0": lambda m: m.fundamental_value_0,
                "FundamentalValue_1": lambda m: m.fundamental_value_1,
                "FundamentalValue_2": lambda m: m.fundamental_value_2,
                "FundamentalValue_3": lambda m: m.fundamental_value_3
            }
        )

    def update_fundamental_value_0(self):
        # Sabit etki
        # news_history'deki son haberi kullan
        current_news = self.news_history[-1] if self.news_history else 0

        if current_news > 0:
            score_news_0 = current_news * 0.1 # pozitif haber
        elif current_news < 0:
            score_news_0 = current_news * 0.1 # negatif haber. pozitif haber ile aynı tepki
        else:
            score_news_0 = current_news # yeni haber yok

        print(f"Haber/Bilgi_0: {score_news_0}")
        self.prev_fundamental_value_0= self.fundamental_value_0
        self.fundamental_value_0 += self.fundamental_value_0 * score_news_0
        self.fundamental_history_0.append(self.fundamental_value_0)


    def update_fundamental_value_1(self):
        # Asimetrik Etki
        # news_history'deki son haberi kullan
        current_news = self.news_history[-1] if self.news_history else 0

        if current_news > 0:
            score_news_1 = current_news * 0.1 # pozitif haber
        elif current_news < 0:
            score_news_1 = current_news * 0.15 # negatif haber. pozitif haberden daha fazla duyarlılık
        else:
            score_news_1 = current_news # yeni haber yok

        print(f"Haber/Bilgi_1: {score_news_1}")
        self.prev_fundamental_value_1 = self.fundamental_value_1
        self.fundamental_value_1 += self.fundamental_value_1 * score_news_1
        self.fundamental_history_1.append(self.fundamental_value_1)

    def update_fundamental_value_2(self):
        # Güçlenen Etki
        # news_history'deki son haberi kullan
        current_news = self.news_history[-1] if self.news_history else 0
        score_news_2 = 0
        score_news_2 = current_news * 0.1 + score_news_2 * 0.9


        print(f"Haber/Bilgi_2: {score_news_2}")
        self.prev_fundamental_value_2 = self.fundamental_value_2
        self.fundamental_value_2 += self.fundamental_value_2 * score_news_2
        self.fundamental_history_2.append(self.fundamental_value_2)

    def update_fundamental_value_3(self):
        # Sönümlü Etki
        lam=0.8
        # News geçmişini kullan
        num_history_steps = 5
        # Yeterli geçmiş yoksa 0 kabul et
        recent_news = self.news_history[-min(len(self.news_history), num_history_steps):]

        score_news_3 = 0
        for i, news_val in enumerate(reversed(recent_news)):
             score_news_3 += news_val * (lam ** i)
        score_news_3 *= 0.1 # Ölçeklendirme faktörü

        print(f"Haber/Bilgi_3: score_{score_news_3}")
        self.prev_fundamental_value_3 = self.fundamental_value_3
        self.fundamental_value_3 += self.fundamental_value_3 * score_news_3
        self.fundamental_history_3.append(self.fundamental_value_3)

    def update_price(self, demand, supply):
        #Fiyatı arz-talep farkına göre günceller.
        imbalance = demand - supply
        self.prev_price = self.price
        self.price += 0.1 * imbalance  # Duyarlılık katsayısı
        self.price = max(1, self.price)  # Negatif fiyatı engelle
        self.price_history.append(self.price)

    def step(self):
        """Zaman adımını ilerletir."""
        self.step_count += 1


        self.total_demand = 0
        self.total_supply = 0

        # Rastgele haberi oluştur ve geçmişe ekle
        current_news = np.random.choice(self.news_values, p=self.news_probs)
        self.news_history.append(current_news)


        # Agent step method calls execute_action which updates model's total_demand/supply
        # agents.do() metodu çağrılırken, fundamental_strategies, technical_strategies, noise_strategies değişkenlerinin bu scope'ta erişilebilir olması gerekir.
        # __init__ metodunda agentları oluştururken bu strateji listelerine referans verilmişti.
        # Agent step metodları da bu global listeleri kullanıyor. Bu yapı çalışmalı.
        self.agents.do("step")


        self.update_fundamental_value_0()
        self.update_fundamental_value_1()
        self.update_fundamental_value_2()
        self.update_fundamental_value_3()


        # Fiyat güncelle
        self.update_price(self.total_demand, self.total_supply)

        # Print price after update
        print(f"Step {self.step_count}: New Price = {self.price}")


        # Print demand and supply before price update
        print(f"Step {self.step_count}: Demand = {self.total_demand}, Supply = {self.total_supply}")




        # Veri topla
        self.datacollector.collect(self)

    def run_model(self, steps=100):
        for _ in range(steps):
            self.step()

# Modeli çalıştır
model = MarketModel(num_fundamental=400, num_technical=0, num_noise=0)
model.run_model(steps=1000) # 1000 adım çalıştır

# Get the data from the DataCollector
results_df = model.datacollector.get_model_vars_dataframe()

# Grafik oluşturma (tek eksenli)
plt.figure(figsize=(12, 6))

# Fiyatı çiz
plt.plot(results_df.index, results_df["Price"], label="Fiyat", color='tab:blue')

# Temel değerleri aynı eksene çiz
plt.plot(results_df.index, results_df["FundamentalValue_0"], label="Temel Değer 0", color='tab:red', linestyle='--')
plt.plot(results_df.index, results_df["FundamentalValue_1"], label="Temel Değer 1", color='tab:green', linestyle=':')
plt.plot(results_df.index, results_df["FundamentalValue_2"], label="Temel Değer 2", color='tab:orange', linestyle='-.')
plt.plot(results_df.index, results_df["FundamentalValue_3"], label="Temel Değer 3", color='tab:purple', linestyle='--')

# Eksen etiketleri ve başlık
plt.xlabel('Zaman Adımı')
plt.ylabel('Değer')
plt.title("Zamanla Fiyat ve Temel Değerlerin Değişimi (Sadece Temel Ajanlar)")

# Grid ekle
plt.grid(True)

# Legend ekle
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd # pandas'ı import ettiğinizden emin olun

# MarketModel sınıfınızın tanımlandığından emin olun (önceki hücreyi çalıştırarak)
# Agent ve strategy tanımlarının da yapıldığından emin olun

# Sadece temel ajanlarla simülasyon
# Daha önce düzeltilen MarketModel sınıfını kullanın
model = MarketModel(num_fundamental=400, num_technical=0, num_noise=0)
model.run_model(steps=100)

# Get the data from the DataCollector
# DataCollector artık fundamental_value_0'ı "FundamentalValue_0" sütununda topluyor
results_df = model.datacollector.get_model_vars_dataframe()

# Fiyatları ve Temel Değeri çiz

fig, ax1 = plt.subplots(figsize=(12, 6)) # Grafik boyutunu büyütelim ve ilk ekseni oluştur

# Birincil Y ekseni (Sol): Fiyat
color = 'tab:blue'
ax1.set_xlabel('Zaman Adımı')
ax1.set_ylabel('Fiyat', color=color)
ax1.plot(results_df.index, results_df["Price"], label="Fiyat", color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True)

# İkincil Y ekseni (Sağ): Temel Değer
ax2 = ax1.twinx() # x eksenini paylaşan ikinci ekseni oluştur
color = 'tab:red' # Farklı bir renk kullanalım
ax2.set_ylabel('Temel Değer', color=color)
# DataCollector'daki FundamentalValue_0 sütununu kullanın
ax2.plot(results_df.index, results_df["FundamentalValue_0"], label="Temel Değer", color=color, linestyle='--')
ax2.tick_params(axis='y', labelcolor=color)

# Grafik başlığı
plt.title("Zamanla Fiyat ve Temel Değer Değişimi (Sadece Temel Ajanlar)")

# Legend'ları birleştirme (İsteğe bağlı ama önerilir)
# ax1 ve ax2'deki tüm çizgileri al
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left') # Legend'ı sol üste koy

fig.tight_layout() # Grafik düzenlemesini otomatik ayarla
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# MarketModel sınıfınızın ve ajan/strateji tanımlarınızın çalıştığından emin olun.
# DataCollector'ın tüm fundamental_value'ları topladığından emin olun.

# Modeli çalıştır
model = MarketModel(num_fundamental=400, num_technical=0, num_noise=0)
model.run_model(steps=100)

# DataCollector'dan veriyi al
results_df = model.datacollector.get_model_vars_dataframe()

# Grafik oluşturma (tek eksenli)
plt.figure(figsize=(12, 6)) # Grafik boyutunu ayarla

# Fiyatı çiz
plt.plot(results_df.index, results_df["Price"], label="Fiyat", color='tab:blue')

# Temel değerleri aynı eksene çiz
plt.plot(results_df.index, results_df["FundamentalValue_0"], label="Temel Değer 0", color='tab:red', linestyle='--')
plt.plot(results_df.index, results_df["FundamentalValue_1"], label="Temel Değer 1", color='tab:green', linestyle=':')
plt.plot(results_df.index, results_df["FundamentalValue_2"], label="Temel Değer 2", color='tab:orange', linestyle='-.')
plt.plot(results_df.index, results_df["FundamentalValue_3"], label="Temel Değer 3", color='tab:purple', linestyle='--')

# Eksen etiketleri ve başlık
plt.xlabel('Zaman Adımı')
plt.ylabel('Değer') # Tek bir Y ekseni için genel başlık
plt.title("Zamanla Fiyat ve Temel Değerlerin Değişimi (Sadece Temel Ajanlar)")

# Grid ekle
plt.grid(True)

# Legend ekle
plt.legend(loc='upper left') # Tüm çizgiler için tek bir legend

plt.tight_layout() # Grafik düzenlemesini otomatik ayarla
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd # pandas'ı import ettiğinizden emin olun

# MarketModel sınıfınızın tanımlandığından emin olun (önceki hücreyi çalıştırarak)
# Agent ve strategy tanımlarının da yapıldığından emin olun

# Sadece temel ajanlarla simülasyon
# Daha önce düzeltilen MarketModel sınıfını kullanın
model = MarketModel(num_fundamental=400, num_technical=0, num_noise=0)
model.run_model(steps=100)

# Get the data from the DataCollector
# DataCollector artık tüm fundamental_value'ları ilgili sütunlarda topluyor
results_df = model.datacollector.get_model_vars_dataframe()

# Fiyatları ve Temel Değerleri çiz

fig, ax1 = plt.subplots(figsize=(12, 6)) # Grafik boyutunu büyütelim ve ilk ekseni oluştur

# Birincil Y ekseni (Sol): Fiyat
color = 'tab:blue'
ax1.set_xlabel('Zaman Adımı')
ax1.set_ylabel('Fiyat', color=color)
ax1.plot(results_df.index, results_df["Price"], label="Fiyat", color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(True)

# İkincil Y ekseni (Sağ): Temel Değerler
ax2 = ax1.twinx() # x eksenini paylaşan ikinci ekseni oluştur
ax2.set_ylabel('Temel Değerler') # Ortak bir başlık kullanalım

# Farklı temel değerleri farklı renklerle çiz
ax2.plot(results_df.index, results_df["FundamentalValue_0"], label="Temel Değer 0: Temel Etki", color='tab:red', linestyle='--')
ax2.plot(results_df.index, results_df["FundamentalValue_1"], label="Temel Değer 1: Asimetrik Etki", color='tab:green', linestyle=':') # Farklı linestyle
ax2.plot(results_df.index, results_df["FundamentalValue_2"], label="Temel Değer 2: Güçlenen Etki", color='tab:orange', linestyle='-.') # Farklı linestyle
ax2.plot(results_df.index, results_df["FundamentalValue_3"], label="Temel Değer 3: Sönümlü Etki", color='tab:purple', linestyle='--') # Farklı renk ve linestyle

ax2.tick_params(axis='y') # İkincil eksen için tick ayarlamaları

# Grafik başlığı
plt.title("Zamanla Fiyat ve Temel Değerlerin Değişimi (Sadece Temel Ajanlar)")

# Legend'ları birleştirme
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left') # Legend'ı sol üste koy

fig.tight_layout() # Grafik düzenlemesini otomatik ayarla
plt.show()
# Out:
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 1: New Price = 100.0
# Step 1: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.2
# Haber/Bilgi_1: -0.3
# Haber/Bilgi_2: -0.2
# Step 2: New Price = 100.0
# Step 2: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 3: New Price = 100.0
# Step 3: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 4: New Price = 100.0
# Step 4: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 5: New Price = 100.0
# Step 5: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 6: New Price = 110.0
# Step 6: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 7: New Price = 110.0
# Step 7: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 8: New Price = 110.0
# Step 8: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 9: New Price = 110.0
# Step 9: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 10: New Price = 120.0
# Step 10: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 11: New Price = 130.0
# Step 11: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 12: New Price = 130.0
# Step 12: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 13: New Price = 120.0
# Step 13: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 14: New Price = 120.0
# Step 14: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 15: New Price = 120.0
# Step 15: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 16: New Price = 120.0
# Step 16: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 17: New Price = 120.0
# Step 17: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 18: New Price = 110.0
# Step 18: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 19: New Price = 120.0
# Step 19: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 20: New Price = 120.0
# Step 20: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 21: New Price = 110.0
# Step 21: Demand = 0, Supply = 100
# Haber/Bilgi_0: -0.2
# Haber/Bilgi_1: -0.3
# Haber/Bilgi_2: -0.2
# Step 22: New Price = 110.0
# Step 22: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 23: New Price = 100.0
# Step 23: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 24: New Price = 100.0
# Step 24: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 25: New Price = 110.0
# Step 25: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 26: New Price = 120.0
# Step 26: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 27: New Price = 110.0
# Step 27: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 28: New Price = 120.0
# Step 28: Demand = 100, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 29: New Price = 130.0
# Step 29: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 30: New Price = 120.0
# Step 30: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 31: New Price = 130.0
# Step 31: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 32: New Price = 130.0
# Step 32: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 33: New Price = 140.0
# Step 33: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 34: New Price = 150.0
# Step 34: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 35: New Price = 150.0
# Step 35: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 36: New Price = 160.0
# Step 36: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 37: New Price = 180.0
# Step 37: Demand = 200, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 38: New Price = 190.0
# Step 38: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 39: New Price = 200.0
# Step 39: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 40: New Price = 210.0
# Step 40: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 41: New Price = 220.0
# Step 41: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 42: New Price = 220.0
# Step 42: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 43: New Price = 220.0
# Step 43: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 44: New Price = 210.0
# Step 44: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 45: New Price = 210.0
# Step 45: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 46: New Price = 220.0
# Step 46: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 47: New Price = 220.0
# Step 47: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 48: New Price = 220.0
# Step 48: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 49: New Price = 220.0
# Step 49: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 50: New Price = 210.0
# Step 50: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 51: New Price = 210.0
# Step 51: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 52: New Price = 210.0
# Step 52: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 53: New Price = 210.0
# Step 53: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 54: New Price = 210.0
# Step 54: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 55: New Price = 220.0
# Step 55: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 56: New Price = 220.0
# Step 56: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.2
# Haber/Bilgi_1: -0.3
# Haber/Bilgi_2: -0.2
# Step 57: New Price = 220.0
# Step 57: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 58: New Price = 210.0
# Step 58: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 59: New Price = 220.0
# Step 59: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 60: New Price = 220.0
# Step 60: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 61: New Price = 220.0
# Step 61: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 62: New Price = 220.0
# Step 62: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.2
# Haber/Bilgi_1: -0.3
# Haber/Bilgi_2: -0.2
# Step 63: New Price = 220.0
# Step 63: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 64: New Price = 210.0
# Step 64: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 65: New Price = 210.0
# Step 65: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 66: New Price = 210.0
# Step 66: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 67: New Price = 220.0
# Step 67: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 68: New Price = 220.0
# Step 68: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 69: New Price = 220.0
# Step 69: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 70: New Price = 220.0
# Step 70: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 71: New Price = 220.0
# Step 71: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 72: New Price = 220.0
# Step 72: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 73: New Price = 220.0
# Step 73: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 74: New Price = 220.0
# Step 74: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 75: New Price = 220.0
# Step 75: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 76: New Price = 210.0
# Step 76: Demand = 0, Supply = 100
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 77: New Price = 210.0
# Step 77: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 78: New Price = 200.0
# Step 78: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 79: New Price = 190.0
# Step 79: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 80: New Price = 200.0
# Step 80: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 81: New Price = 200.0
# Step 81: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 82: New Price = 210.0
# Step 82: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 83: New Price = 230.0
# Step 83: Demand = 200, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 84: New Price = 240.0
# Step 84: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 85: New Price = 230.0
# Step 85: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0.1
# Haber/Bilgi_1: 0.1
# Haber/Bilgi_2: 0.1
# Step 86: New Price = 240.0
# Step 86: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 87: New Price = 250.0
# Step 87: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 88: New Price = 260.0
# Step 88: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 89: New Price = 260.0
# Step 89: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 90: New Price = 260.0
# Step 90: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.2
# Haber/Bilgi_1: -0.3
# Haber/Bilgi_2: -0.2
# Step 91: New Price = 260.0
# Step 91: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 92: New Price = 250.0
# Step 92: Demand = 0, Supply = 100
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 93: New Price = 250.0
# Step 93: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0.2
# Haber/Bilgi_1: 0.2
# Haber/Bilgi_2: 0.2
# Step 94: New Price = 250.0
# Step 94: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 95: New Price = 260.0
# Step 95: Demand = 100, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 96: New Price = 260.0
# Step 96: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 97: New Price = 260.0
# Step 97: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 98: New Price = 260.0
# Step 98: Demand = 0, Supply = 0
# Haber/Bilgi_0: -0.1
# Haber/Bilgi_1: -0.15
# Haber/Bilgi_2: -0.1
# Step 99: New Price = 260.0
# Step 99: Demand = 0, Supply = 0
# Haber/Bilgi_0: 0
# Haber/Bilgi_1: 0
# Haber/Bilgi_2: 0.0
# Step 100: New Price = 250.0
# Step 100: Demand = 0, Supply = 100

# %% [markdown]
# -----TEMEL AJANLAR ---------
#
# - Temel Etki (anında)
# - Asimetrik Etki (anında)
# - Güçlenen Etki (gecikmeli-hafızalı)
# - Sönümlü Etki (gecikmeli-hafızalı)
#
# ANINDA ETKİ VS GECİKMELİ ETKİ
#
# - Haber/bilgi olumlu/olumsuz iken hangisi (anında/gecikmeli), piyasayı tersi yönde götürebiliyor ya da dirençli yapabiliyor? Hangi oran bunu sağlıyor?
#
# - Kümülatif haber grafiği ile ters hareket eden oran hangisidir?
#
# - Birinci deneyde anında = gecikmeli
#
# - İkinci deneyde anında eşit değil gecikmeli

# %%
# !pip install mesa[rec]
# !pip install seaborn

# Has multi-dimensional arrays and matrices.
# Has a large collection of mathematical functions to operate on these arrays.
import numpy as np

# Data manipulation and analysis.
import pandas as pd

# Data visualization tools.
import seaborn as sns

import mesa

import random
# Out:
# Collecting mesa[rec]
#   Downloading mesa-3.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (1.15.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (4.67.1)
# Requirement already satisfied: altair in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (5.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (3.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (3.4.2)
# Collecting solara (from mesa[rec])
#   Downloading solara-1.47.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (1.40.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (4.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->mesa[rec]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->mesa[rec]) (2025.2)
# Collecting solara-server==1.47.0 (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading solara_server-1.47.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting solara-ui==1.47.0 (from solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading solara_ui-1.47.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: click>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (8.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (3.18.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (6.17.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.11/dist-packages (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (6.1.12)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (5.10.4)
# Collecting rich-click (from solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading rich_click-1.8.9-py3-none-any.whl.metadata (7.9 kB)
# Collecting watchdog (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.7 MB/s eta 0:00:00
# Collecting watchfiles (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting starlette (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading starlette-0.47.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting uvicorn (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec])
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: websockets in /usr/local/lib/python3.11/dist-packages (from solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (15.0.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (4.12.3)
# Collecting ipyvue>=1.9.0 (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading ipyvue-1.11.2-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting ipyvuetify>=1.6.10 (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading ipyvuetify-1.11.1-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets>=7.7 in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (7.7.1)
# Collecting reacton>=1.9 (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading reacton-1.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (2.32.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.47.0->solara->mesa[rec]) (5.5.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.47.0->solara->mesa[rec]) (3.8)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.47.0->solara->mesa[rec]) (2.19.1)
# Collecting pymdown-extensions (from solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading pymdown_extensions-10.15-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (0.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mesa[rec]) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair->mesa[rec]) (3.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.0.15)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (6.4.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (5.7.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (2.21.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from pymdown-extensions->solara-ui[all]==1.47.0->solara->mesa[rec]) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (2025.4.26)
# Requirement already satisfied: rich>=10.7 in /usr/local/lib/python3.11/dist-packages (from rich-click->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (13.9.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (4.9.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (1.3.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (4.3.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.7->rich-click->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (3.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click->solara-server==1.47.0->solara-server[dev,starlette]==1.47.0->solara->mesa[rec]) (0.1.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (23.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.22.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.2.13)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (2.22)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.47.0->solara-ui[all]==1.47.0->solara->mesa[rec]) (1.8.0)
# Downloading mesa-3.2.0-py3-none-any.whl (197 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.0/197.0 kB 10.6 MB/s eta 0:00:00
# Downloading solara-1.47.0-py3-none-any.whl (5.9 kB)
# Downloading solara_server-1.47.0-py3-none-any.whl (3.9 kB)
# Downloading solara_ui-1.47.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.5 MB/s eta 0:00:00
# Downloading ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 61.8 MB/s eta 0:00:00
# Downloading ipyvuetify-1.11.1-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 82.9 MB/s eta 0:00:00
# Downloading reacton-1.9.1-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 8.6 MB/s eta 0:00:00
# Downloading pymdown_extensions-10.15-py3-none-any.whl (265 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.8/265.8 kB 18.7 MB/s eta 0:00:00
# Downloading rich_click-1.8.9-py3-none-any.whl (36 kB)
# Downloading starlette-0.47.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.8/72.8 kB 6.0 MB/s eta 0:00:00
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 4.7 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.6 MB/s eta 0:00:00
# Downloading watchfiles-1.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 26.7 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.3 MB/s eta 0:00:00
# Installing collected packages: watchdog, uvicorn, pymdown-extensions, jedi, watchfiles, starlette, rich-click, mesa, reacton, ipyvue, ipyvuetify, solara-ui, solara-server, solara
# Successfully installed ipyvue-1.11.2 ipyvuetify-1.11.1 jedi-0.19.2 mesa-3.2.0 pymdown-extensions-10.15 reacton-1.9.1 rich-click-1.8.9 solara-1.47.0 solara-server-1.47.0 solara-ui-1.47.0 starlette-0.47.0 uvicorn-0.34.2 watchdog-6.0.0 watchfiles-1.0.5
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import random

# === FUNDAMENTAL AGENT STRATEGIES ===
def fundamental_strategy_0(agent, model):
    #Temel Etki
    #print(f"Fundamental_strategy_0 aktif")
    if model.price < model.fundamental_value_0:
        return "buy"
    elif model.price > model.fundamental_value_0:
        return "sell"
    return "hold"

def fundamental_strategy_1(agent, model):
    # Asimetrik
    #print(f"Fundamental_strategy_1 aktif")
    if model.price < model.fundamental_value_1:
        return "buy"
    elif model.price > model.fundamental_value_1:
        return "sell"
    return "hold"

def fundamental_strategy_2(agent, model):
    # Güçlenen
    #print(f"Fundamental_strategy_2 aktif")
    if model.price < model.fundamental_value_2:
        return "buy"
    elif model.price > model.fundamental_value_2:
        return "sell"
    return "hold"
"""
def fundamental_strategy_3(agent, model):
    # Sönümlü
    #print(f"Fundamental_strategy_3 aktif")
    if model.price < model.fundamental_value_3:
        return "buy"
    elif model.price > model.fundamental_value_3:
        return "sell"
    return "hold"
"""



fundamental_strategies = [
    fundamental_strategy_0,
    fundamental_strategy_1,
    fundamental_strategy_2#,
    #fundamental_strategy_3
]

# === TECHNICAL AGENT STRATEGIES ===
def technical_strategy_0(agent, model):
    """Basit Momentum: Fiyat yükseliyorsa al."""
    if model.price > model.prev_price:
        return "buy"
    elif model.price < model.prev_price:
        return "sell"
    return "hold"

def technical_strategy_1(agent, model):
    """Tersine Tepki: Fiyat düşüyorsa al."""
    if model.price < model.prev_price:
        return "buy"
    elif model.price > model.prev_price:
        return "sell"
    return "hold"

def technical_strategy_2(agent, model):
    """Rastgele Momentum: %60 ihtimalle trend takibi"""
    if random.random() < 0.6:
        return technical_strategy_0(agent, model)
    else:
        return "hold"

def technical_strategy_3(agent, model):
    """Trend Dönüşü: Son üç fiyatı analiz et."""
    history = model.price_history
    if len(history) >= 3:
        if history[-1] > history[-2] > history[-3]:
            return "sell"
        elif history[-1] < history[-2] < history[-3]:
            return "buy"
    return "hold"

technical_strategies = [
    technical_strategy_0,
    technical_strategy_1,
    technical_strategy_2,
    technical_strategy_3
]

# === NOISE AGENT STRATEGIES ===
def noise_strategy_0(agent, model):
    """Rastgele işlem."""
    return random.choice(["buy", "sell", "hold"])

def noise_strategy_1(agent, model):
    """Daha çok hold eğilimli rastgele işlem."""
    return random.choices(["buy", "sell", "hold"], weights=[0.2, 0.2, 0.6])[0]

def noise_strategy_2(agent, model):
    """Fiyatın çift/tek olmasına göre karar verir."""
    if int(model.price) % 2 == 0:
        return "buy"
    else:
        return "sell"

def noise_strategy_3(agent, model):
    """Rastgele ancak varlığı olanlar daha çok satar."""
    if agent.asset > 0 and random.random() < 0.6:
        return "sell"
    return random.choice(["buy", "hold"])

noise_strategies = [
    noise_strategy_0,
    noise_strategy_1,
    noise_strategy_2,
    noise_strategy_3
]

##############################----------AGENT--------------#######################

class BaseAgent(mesa.Agent):
    def __init__(self, model, agent_type, strategy_id):
        super().__init__(model)
        self.agent_type = agent_type  # 'fundamental', 'technical', 'noise'
        self.strategy_id = strategy_id  # 0, 1, 2, 3 (her tür için 4 strateji)
        self.cash = 100000.0
        self.asset = 1000
        self.last_action = None  # 'buy', 'sell', 'hold'

    def step(self):
        raise NotImplementedError("This method should be implemented by subclasses.")


class FundamentalAgent(BaseAgent):
    def __init__(self, model, strategy_id):
        super().__init__(model, "fundamental", strategy_id)

    def step(self):
        #from strategies import fundamental_strategies
        action = fundamental_strategies[self.strategy_id](self, self.model)
        self.execute_action(action)

    def execute_action(self, action):
        price = self.model.price
        if action == "buy" and self.cash >= price:
            self.asset += 1
            self.cash -= price
            self.model.total_demand += 1
        elif action == "sell" and self.asset > 0:
            self.asset -= 1
            self.cash += price
            self.model.total_supply += 1
        self.last_action = action


class TechnicalAgent(BaseAgent):
    def __init__(self, model, strategy_id):
        super().__init__(model, "technical", strategy_id)

    def step(self):
        #from strategies import technical_strategies
        action = technical_strategies[self.strategy_id](self, self.model)
        self.execute_action(action)

    def execute_action(self, action):
        price = self.model.price
        if action == "buy" and self.cash >= price:
            self.asset += 1
            self.cash -= price
            self.model.total_demand += 1
        elif action == "sell" and self.asset > 0:
            self.asset -= 1
            self.cash += price
            self.model.total_supply += 1
        self.last_action = action


class NoiseAgent(BaseAgent):
    def __init__(self, model, strategy_id):
        super().__init__(model, "noise", strategy_id)

    def step(self):
        #from strategies import noise_strategies
        action = noise_strategies[self.strategy_id](self, self.model)
        self.execute_action(action)

    def execute_action(self, action):
        price = self.model.price
        if action == "buy" and self.cash >= price:
            self.asset += 1
            self.cash -= price
            self.model.total_demand += 1
        elif action == "sell" and self.asset > 0:
            self.asset -= 1
            self.cash += price
            self.model.total_supply += 1
        self.last_action = action

#############################------------MODEL---------------#######################

from mesa.datacollection import DataCollector
#from agents import FundamentalAgent, TechnicalAgent, NoiseAgent
#from strategies import fundamental_strategies, technical_strategies, noise_strategies
import random

class MarketModel(mesa.Model):
    def __init__(self,
                 num_fundamental=400,
                 num_technical=400,
                 num_noise=400,
                 initial_price=100,
                 initial_fundamental_value=100):
        super().__init__()

        # Initialize total_demand and total_supply attributes
        self.total_demand = 0
        self.total_supply = 0


        self.price = initial_price
        self.prev_price = initial_price
        self.fundamental_value_0= initial_fundamental_value
        self.fundamental_value_1 = initial_fundamental_value
        self.fundamental_value_2 = initial_fundamental_value
        #self.fundamental_value_3 = initial_fundamental_value


        self.prev_fundamental_value_0= initial_fundamental_value
        self.prev_fundamental_value_1 = initial_fundamental_value
        self.prev_fundamental_value_2 = initial_fundamental_value
        #self.prev_fundamental_value_3 = initial_fundamental_value

        self.price_history = [initial_price]
        self.fundamental_history_0 = [initial_fundamental_value]
        self.fundamental_history_1 = [initial_fundamental_value]
        self.fundamental_history_2 = [initial_fundamental_value]
        #self.fundamental_history_3 = [initial_fundamental_value]

        self.step_count = 0


        self.news = 0
        self.news_history = []
        # Haber dağılımı
        self.news_values = [-2, -1, 0, 1, 2]
        self.news_probs = [0.05, 0.20, 0.50, 0.20, 0.05]

        self.cumulatif_news = 0

        self.old_news = 0

        self.imbalance = 0
        self.imbalance_history = []

        self.score_news_2 = 0



        # Ajanları oluştur
        # Fundamental agents
        for i in range(num_fundamental):
            strat_index = i % 3
            agent = FundamentalAgent(self, strat_index)
            self.agents.add(agent)

        # Technical agents
        for i in range(num_technical):
            strat_index = i % 4
            agent = TechnicalAgent(self, strat_index)
            self.agents.add(agent)

        # Noise agents
        for i in range(num_noise):
            strat_index = i % 4
            agent = NoiseAgent(self, strat_index)
            self.agents.add(agent)

        # DataCollector'ı tüm fundamental_value'ları içerecek şekilde güncelle
        self.datacollector = DataCollector(
            model_reporters={
                "Price": lambda m: m.price,
                "FundamentalValue_0": lambda m: m.fundamental_value_0,
                "FundamentalValue_1": lambda m: m.fundamental_value_1,
                "FundamentalValue_2": lambda m: m.fundamental_value_2,
                #"FundamentalValue_3": lambda m: m.fundamental_value_3,
                "CurrentNews": lambda m: m.news, # current_news'u ekledik
                "CumulatifNews": lambda m: m.cumulatif_news # <-- Yeni: CumulatifNews'u ekledik
            }
        )

    def update_fundamental_value_0(self):
        # Sabit etki

        if self.news > 0:
            score_news_0 = self.news * 0.1  # pozitif haber
        elif self.news < 0:
            score_news_0 = self.news * 0.1  # negatif haber. pozitif haber ile aynı tepki
        else:
            score_news_0 = self.news # yeni haber yok


        print(f"Haber/Bilgi_0: {self.news}")
        print(f"Haber/Bilgi_0 - Değeri: {score_news_0}")
        self.prev_fundamental_value_0= self.fundamental_value_0
        print(f"prev_fundamental_value_0: {self.prev_fundamental_value_0}")
        self.fundamental_value_0 += self.fundamental_value_0 * score_news_0
        print(f"fundamental_value_0: {self.fundamental_value_0}")
        self.fundamental_history_0.append(self.fundamental_value_0)


    def update_fundamental_value_1(self):
        # Asimetrik Etki
        if self.news > 0:
            score_news_1 = self.news * 0.1 # pozitif haber
        elif self.news < 0:
            score_news_1 = self.news * 0.12  # negatif haber. pozitif haberden daha fazla duyarlılık
        else:
            score_news_1 = self.news # yeni haber yok

        print(f"Haber/Bilgi_1: {self.news}")
        print(f"Haber/Bilgi_1 - Değeri: {score_news_1}")
        self.prev_fundamental_value_1 = self.fundamental_value_1
        print(f"prev_fundamental_value_1: {self.prev_fundamental_value_1}")
        self.fundamental_value_1 += self.fundamental_value_1 * score_news_1
        print(f"fundamental_value_1: {self.fundamental_value_1}")
        self.fundamental_history_1.append(self.fundamental_value_1)

    """def update_fundamental_value_2(self):
        # Güçlenen Etki

        self.old_news += self.news * 0.1

        self.score_news_2 = self.old_news
        print(f"score_news_2: {self.score_news_2}")


        print(f"Haber/Bilgi_2: {self.news}")
        print(f"Haber/Bilgi_2 - Değeri: {self.score_news_2}")
        self.prev_fundamental_value_2 = self.fundamental_value_2
        print(f"prev_fundamental_value_2: {self.prev_fundamental_value_2}")
        self.fundamental_value_2 += (self.fundamental_value_2 * self.score_news_2)
        print(f"fundamental_value_2: {self.fundamental_value_2}")
        self.fundamental_history_2.append(self.fundamental_value_2)"""




    # Haber hafıza fonksiyonu
    def update_fundamental_value_2(self):
        lam=0.9
        memory_length=10
        #signal = []
        memory = 0 # Initialize memory for the current step
        for k in range(1, memory_length + 1):
            if len(self.news_history) - k >= 0: # Check if the history index is valid
                memory += (lam ** k) * self.news_history[len(self.news_history) - k]



        #return np.array(signal)

        print(f"Haber/Bilgi_2: {self.news}")
        print(f"Haber/Bilgi_2 - Değeri: {memory}")
        self.prev_fundamental_value_2 = self.fundamental_value_2
        print(f"prev_fundamental_value_2: {self.prev_fundamental_value_2}")
        self.fundamental_value_2 = (self.fundamental_value_2 + memory)
        print(f"fundamental_value_2: {self.fundamental_value_2}")
        self.fundamental_history_2.append(self.fundamental_value_2)








    """def update_fundamental_value_3(self):
        # Sönümlü Etki
        lam = 0.8
        num_history_steps = 5
        score_news_3 = 0

        # Haber geçmişinden son N adımı al (N=num_history_steps)
        # news_history listesi self.step metodunda dolduruluyor.
        # len(self.news_history) modelin çalıştığı adım sayısıdır.
        # İlk adımlarda len(self.news_history) 5'ten küçük olacaktır.
        # Sadece mevcut olan geçmiş adımları kullan.

        # Geçmişten alınacak adım sayısı, haber geçmişinin uzunluğu ve istenen maksimum adım sayısı arasındaki minimum değerdir.
        steps_to_consider = min(len(self.news_history), num_history_steps)

        # En güncel haberden başlayarak (yani en sondan) geriye doğru döngü yap
        # news_history[-steps_to_consider:] son 'steps_to_consider' elemanı verir.
        # reversed() ile bunu tersten okuyarak en güncel haberi (indeks 0) ilk işleriz.
        recent_news = self.news_history[-steps_to_consider:]

        for i, news_val in enumerate(reversed(recent_news)):
             score_news_3 += news_val * (lam ** i)

        score_news_3 *= 0.1 # Ölçeklendirme faktörü


        print(f"Haber/Bilgi_3: score_{self.news}")
        print(f"Haber/Bilgi_3 - Değeri: {score_news_3}")
        self.prev_fundamental_value_3 = self.fundamental_value_3
        print(f"prev_fundamental_value_3: {self.prev_fundamental_value_3}")
        self.fundamental_value_3 += self.fundamental_value_3 * score_news_3
        print(f"fundamental_value_3: {self.fundamental_value_3}")
        self.fundamental_history_3.append(self.fundamental_value_3)"""

    def update_price(self, demand, supply):
        #Fiyatı arz-talep farkına göre günceller.
        imbalance = demand - supply
        self.prev_price = self.price
        self.price += 0.1 * imbalance  # Duyarlılık katsayısı
        self.price = max(1, self.price)  # Negatif fiyatı engelle
        self.price_history.append(self.price)

    def step(self):
        """Zaman adımını ilerletir."""
        self.step_count += 1


        self.total_demand = 0
        self.total_supply = 0

        self.news = np.random.choice(self.news_values, p=self.news_probs)
        self.news_history.append(self.news)
        self.cumulatif_news += self.news



        # Agent step method calls execute_action which updates model's total_demand/supply
        self.agents.do("step")

        self.imbalance = self.total_demand -self.total_supply
        self.imbalance_history.append(self.imbalance)


        self.update_fundamental_value_0()
        self.update_fundamental_value_1()
        self.update_fundamental_value_2()
        #self.update_fundamental_value_3()


        # Fiyat güncelle
        self.update_price(self.total_demand, self.total_supply)

        # Print price after update
        print(f"Step {self.step_count}: New Price = {self.price}")


        # Print demand and supply before price update
        print(f"Step {self.step_count}: Demand = {self.total_demand}, Supply = {self.total_supply}")




        # Veri topla
        self.datacollector.collect(self)

    def run_model(self, steps=100):
        for _ in range(steps):
            print(f"---------------------Step {_ + 1}--------------")
            self.step()


############################### --------SİMÜLASYON VE GÖRSELLEŞTİRME--------###########

import matplotlib.pyplot as plt


# Modeli çalıştır
model = MarketModel(num_fundamental=400, num_technical=0, num_noise=0)
model.run_model(steps=500) # 100 adım çalıştır

# DataCollector'dan veriyi al
results_df = model.datacollector.get_model_vars_dataframe()


# === Fiyat ve Temel Değerler Grafiği ===
plt.figure(figsize=(12, 6)) # Grafik boyutunu ayarla

# Fiyatı çiz
plt.plot(results_df.index, results_df["Price"], label="Fiyat", color='tab:blue')

# Temel değerleri aynı eksene çiz
plt.plot(results_df.index, results_df["FundamentalValue_0"], label="Temel Değer 0", color='tab:red', linestyle='--')
plt.plot(results_df.index, results_df["FundamentalValue_1"], label="Temel Değer 1", color='tab:green', linestyle=':')
plt.plot(results_df.index, results_df["FundamentalValue_2"], label="Temel Değer 2", color='tab:orange', linestyle='-.')
#plt.plot(results_df.index, results_df["FundamentalValue_3"], label="Temel Değer 3", color='tab:purple', linestyle='--')

# Eksen etiketleri ve başlık
plt.xlabel('Zaman Adımı')
plt.ylabel('Değer') # Tek bir Y ekseni için genel başlık
plt.title("Zamanla Fiyat ve Temel Değerlerin Değişimi (Sadece Temel Ajanlar)")

# Grid ekle
plt.grid(True)

# Legend ekle
plt.legend(loc='upper left') # Tüm çizgiler için tek bir legend

plt.tight_layout() # Grafik düzenlemesini otomatik ayarla
plt.show()

# === Haber Değerleri Grafiği (Ayrı Bir Grafik) ===
plt.figure(figsize=(12, 4)) # Haber için daha küçük bir grafik boyutu

# CurrentNews'u çiz
plt.plot(results_df.index, results_df["CurrentNews"],
         label="Güncel Haber",
         color='tab:gray',
         linestyle='-',
         marker='.',
         markersize=5) # Marker boyutunu artır

plt.xlabel('Zaman Adımı')
plt.ylabel('Haber Değeri')
plt.title('Zamanla Güncel Haber Değerlerinin Değişimi')
plt.grid(True)
# Y ekseni tiklerini belirlediğiniz değerlerle ayarla
plt.yticks([-2, -1, 0, 1, 2])
plt.legend()
plt.tight_layout()
plt.show()

# === Kümülatif Haber Grafiği (Yeni Grafik) ===
plt.figure(figsize=(12, 4)) # Grafik boyutu

# CumulatifNews'u çiz
plt.plot(results_df.index, results_df["CumulatifNews"],
         label="Kümülatif Haber",
         color='tab:red', # Farklı bir renk
         linestyle='-',
         marker='o',      # Farklı bir marker
         markersize=5)

plt.xlabel('Zaman Adımı')
plt.ylabel('Kümülatif Haber Değeri')
plt.title('Zamanla Kümülatif Haber Değerlerinin Değişimi')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------Step 1--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 100
# fundamental_value_0: 100
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 100
# fundamental_value_1: 100
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.0
# prev_fundamental_value_2: 100
# fundamental_value_2: 100.0
# Step 1: New Price = 100.0
# Step 1: Demand = 0, Supply = 0
# ---------------------Step 2--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 100
# fundamental_value_0: 100
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 100
# fundamental_value_1: 100
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.0
# prev_fundamental_value_2: 100.0
# fundamental_value_2: 100.0
# Step 2: New Price = 100.0
# Step 2: Demand = 0, Supply = 0
# ---------------------Step 3--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 100
# fundamental_value_0: 100
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 100
# fundamental_value_1: 100
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.0
# prev_fundamental_value_2: 100.0
# fundamental_value_2: 100.0
# Step 3: New Price = 100.0
# Step 3: Demand = 0, Supply = 0
# ---------------------Step 4--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 100
# fundamental_value_0: 100
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 100
# fundamental_value_1: 100
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.0
# prev_fundamental_value_2: 100.0
# fundamental_value_2: 100.0
# Step 4: New Price = 100.0
# Step 4: Demand = 0, Supply = 0
# ---------------------Step 5--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 100
# fundamental_value_0: 100
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 100
# fundamental_value_1: 100
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.0
# prev_fundamental_value_2: 100.0
# fundamental_value_2: 100.0
# Step 5: New Price = 100.0
# Step 5: Demand = 0, Supply = 0
# ---------------------Step 6--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 100
# fundamental_value_0: 110.0
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 100
# fundamental_value_1: 110.0
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 0.9
# prev_fundamental_value_2: 100.0
# fundamental_value_2: 100.9
# Step 6: New Price = 100.0
# Step 6: Demand = 0, Supply = 0
# ---------------------Step 7--------------
# Haber/Bilgi_0: 2
# Haber/Bilgi_0 - Değeri: 0.2
# prev_fundamental_value_0: 110.0
# fundamental_value_0: 132.0
# Haber/Bilgi_1: 2
# Haber/Bilgi_1 - Değeri: 0.2
# prev_fundamental_value_1: 110.0
# fundamental_value_1: 132.0
# Haber/Bilgi_2: 2
# Haber/Bilgi_2 - Değeri: 2.6100000000000003
# prev_fundamental_value_2: 100.9
# fundamental_value_2: 103.51
# Step 7: New Price = 140.0
# Step 7: Demand = 400, Supply = 0
# ---------------------Step 8--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 132.0
# fundamental_value_0: 118.8
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 132.0
# fundamental_value_1: 116.16
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: 1.4490000000000003
# prev_fundamental_value_2: 103.51
# fundamental_value_2: 104.959
# Step 8: New Price = 100.0
# Step 8: Demand = 0, Supply = 400
# ---------------------Step 9--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 118.8
# fundamental_value_0: 130.68
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 116.16
# fundamental_value_1: 127.776
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 2.2041
# prev_fundamental_value_2: 104.959
# fundamental_value_2: 107.1631
# Step 9: New Price = 140.0
# Step 9: Demand = 400, Supply = 0
# ---------------------Step 10--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 130.68
# fundamental_value_0: 130.68
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 127.776
# fundamental_value_1: 127.776
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.9836900000000002
# prev_fundamental_value_2: 107.1631
# fundamental_value_2: 109.14679
# Step 10: New Price = 100.0
# Step 10: Demand = 0, Supply = 400
# ---------------------Step 11--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 130.68
# fundamental_value_0: 130.68
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 127.776
# fundamental_value_1: 127.776
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.7853210000000002
# prev_fundamental_value_2: 109.14679
# fundamental_value_2: 110.93211099999999
# Step 11: New Price = 140.0
# Step 11: Demand = 400, Supply = 0
# ---------------------Step 12--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 130.68
# fundamental_value_0: 117.61200000000001
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 127.776
# fundamental_value_1: 112.44288
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: 0.7067889
# prev_fundamental_value_2: 110.93211099999999
# fundamental_value_2: 111.6388999
# Step 12: New Price = 100.0
# Step 12: Demand = 0, Supply = 400
# ---------------------Step 13--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 117.61200000000001
# fundamental_value_0: 117.61200000000001
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 112.44288
# fundamental_value_1: 112.44288
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.6361100100000002
# prev_fundamental_value_2: 111.6388999
# fundamental_value_2: 112.27500991
# Step 13: New Price = 140.0
# Step 13: Demand = 400, Supply = 0
# ---------------------Step 14--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 117.61200000000001
# fundamental_value_0: 117.61200000000001
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 112.44288
# fundamental_value_1: 112.44288
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.5724990090000002
# prev_fundamental_value_2: 112.27500991
# fundamental_value_2: 112.84750891899999
# Step 14: New Price = 100.0
# Step 14: Demand = 0, Supply = 400
# ---------------------Step 15--------------
# Haber/Bilgi_0: 2
# Haber/Bilgi_0 - Değeri: 0.2
# prev_fundamental_value_0: 117.61200000000001
# fundamental_value_0: 141.13440000000003
# Haber/Bilgi_1: 2
# Haber/Bilgi_1 - Değeri: 0.2
# prev_fundamental_value_1: 112.44288
# fundamental_value_1: 134.931456
# Haber/Bilgi_2: 2
# Haber/Bilgi_2 - Değeri: 2.3152491081
# prev_fundamental_value_2: 112.84750891899999
# fundamental_value_2: 115.1627580271
# Step 15: New Price = 140.0
# Step 15: Demand = 400, Supply = 0
# ---------------------Step 16--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 141.13440000000003
# fundamental_value_0: 141.13440000000003
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 134.931456
# fundamental_value_1: 134.931456
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.7699136012000003
# prev_fundamental_value_2: 115.1627580271
# fundamental_value_2: 116.9326716283
# Step 16: New Price = 126.8
# Step 16: Demand = 134, Supply = 266
# ---------------------Step 17--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 141.13440000000003
# fundamental_value_0: 141.13440000000003
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 134.931456
# fundamental_value_1: 134.931456
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.9653010489000002
# prev_fundamental_value_2: 116.9326716283
# fundamental_value_2: 117.8979726772
# Step 17: New Price = 140.2
# Step 17: Demand = 267, Supply = 133
# ---------------------Step 18--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 141.13440000000003
# fundamental_value_0: 127.02096000000003
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 134.931456
# fundamental_value_1: 118.73968128
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: 0.28258154010000003
# prev_fundamental_value_2: 117.8979726772
# fundamental_value_2: 118.1805542173
# Step 18: New Price = 126.99999999999999
# Step 18: Demand = 134, Supply = 266
# ---------------------Step 19--------------
# Haber/Bilgi_0: -2
# Haber/Bilgi_0 - Değeri: -0.2
# prev_fundamental_value_0: 127.02096000000003
# fundamental_value_0: 101.61676800000002
# Haber/Bilgi_1: -2
# Haber/Bilgi_1 - Değeri: -0.24
# prev_fundamental_value_1: 118.73968128
# fundamental_value_1: 90.2421577728
# Haber/Bilgi_2: -2
# Haber/Bilgi_2 - Değeri: -1.8594872100000002
# prev_fundamental_value_2: 118.1805542173
# fundamental_value_2: 116.3210670073
# Step 19: New Price = 113.79999999999998
# Step 19: Demand = 134, Supply = 266
# ---------------------Step 20--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 101.61676800000002
# fundamental_value_0: 101.61676800000002
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 90.2421577728
# fundamental_value_1: 90.2421577728
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.6735384890000002
# prev_fundamental_value_2: 116.3210670073
# fundamental_value_2: 114.6475285183
# Step 20: New Price = 100.39999999999998
# Step 20: Demand = 133, Supply = 267
# ---------------------Step 21--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 101.61676800000002
# fundamental_value_0: 111.77844480000002
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 90.2421577728
# fundamental_value_1: 99.26637355008
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: -0.6061846401000002
# prev_fundamental_value_2: 114.6475285183
# fundamental_value_2: 114.04134387820001
# Step 21: New Price = 113.79999999999998
# Step 21: Demand = 267, Supply = 133
# ---------------------Step 22--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 111.77844480000002
# fundamental_value_0: 100.60060032000001
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 99.26637355008
# fundamental_value_1: 87.35440872407041
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -1.1317555799999999
# prev_fundamental_value_2: 114.04134387820001
# fundamental_value_2: 112.9095882982
# Step 22: New Price = 100.39999999999998
# Step 22: Demand = 133, Supply = 267
# ---------------------Step 23--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 100.60060032000001
# fundamental_value_0: 100.60060032000001
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 87.35440872407041
# fundamental_value_1: 87.35440872407041
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.018580022
# prev_fundamental_value_2: 112.9095882982
# fundamental_value_2: 111.89100827620001
# Step 23: New Price = 113.79999999999998
# Step 23: Demand = 267, Supply = 133
# ---------------------Step 24--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 100.60060032000001
# fundamental_value_0: 90.54054028800002
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 87.35440872407041
# fundamental_value_1: 76.87187967718197
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -1.8167220198000003
# prev_fundamental_value_2: 111.89100827620001
# fundamental_value_2: 110.07428625640001
# Step 24: New Price = 73.79999999999998
# Step 24: Demand = 0, Supply = 400
# ---------------------Step 25--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 90.54054028800002
# fundamental_value_0: 90.54054028800002
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 76.87187967718197
# fundamental_value_1: 76.87187967718197
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -2.26267101
# prev_fundamental_value_2: 110.07428625640001
# fundamental_value_2: 107.81161524640001
# Step 25: New Price = 113.79999999999998
# Step 25: Demand = 400, Supply = 0
# ---------------------Step 26--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 90.54054028800002
# fundamental_value_0: 90.54054028800002
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 76.87187967718197
# fundamental_value_1: 76.87187967718197
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -2.036403909
# prev_fundamental_value_2: 107.81161524640001
# fundamental_value_2: 105.77521133740001
# Step 26: New Price = 73.79999999999998
# Step 26: Demand = 0, Supply = 400
# ---------------------Step 27--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 90.54054028800002
# fundamental_value_0: 99.59459431680001
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 76.87187967718197
# fundamental_value_1: 84.55906764490017
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: -0.9327635181000002
# prev_fundamental_value_2: 105.77521133740001
# fundamental_value_2: 104.8424478193
# Step 27: New Price = 113.79999999999998
# Step 27: Demand = 400, Supply = 0
# ---------------------Step 28--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 99.59459431680001
# fundamental_value_0: 99.59459431680001
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 84.55906764490017
# fundamental_value_1: 84.55906764490017
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -0.5256765702000001
# prev_fundamental_value_2: 104.8424478193
# fundamental_value_2: 104.3167712491
# Step 28: New Price = 73.79999999999998
# Step 28: Demand = 0, Supply = 400
# ---------------------Step 29--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 99.59459431680001
# fundamental_value_0: 99.59459431680001
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 84.55906764490017
# fundamental_value_1: 84.55906764490017
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.15451227900000003
# prev_fundamental_value_2: 104.3167712491
# fundamental_value_2: 104.4712835281
# Step 29: New Price = 113.79999999999998
# Step 29: Demand = 400, Supply = 0
# ---------------------Step 30--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 99.59459431680001
# fundamental_value_0: 109.55405374848002
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 84.55906764490017
# fundamental_value_1: 93.01497440939019
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 1.0390610510999998
# prev_fundamental_value_2: 104.4712835281
# fundamental_value_2: 105.51034457920001
# Step 30: New Price = 73.79999999999998
# Step 30: Demand = 0, Supply = 400
# ---------------------Step 31--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 109.55405374848002
# fundamental_value_0: 120.50945912332801
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 93.01497440939019
# fundamental_value_1: 102.31647185032921
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 1.5213443498999997
# prev_fundamental_value_2: 105.51034457920001
# fundamental_value_2: 107.03168892910001
# Step 31: New Price = 113.79999999999998
# Step 31: Demand = 400, Supply = 0
# ---------------------Step 32--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 120.50945912332801
# fundamental_value_0: 108.4585132109952
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 102.31647185032921
# fundamental_value_1: 90.0384952282897
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: 0.7830205110000001
# prev_fundamental_value_2: 107.03168892910001
# fundamental_value_2: 107.81470944010002
# Step 32: New Price = 100.59999999999998
# Step 32: Demand = 134, Supply = 266
# ---------------------Step 33--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 108.4585132109952
# fundamental_value_0: 108.4585132109952
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 90.0384952282897
# fundamental_value_1: 90.0384952282897
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.7047184599
# prev_fundamental_value_2: 107.81470944010002
# fundamental_value_2: 108.51942790000001
# Step 33: New Price = 113.99999999999999
# Step 33: Demand = 267, Supply = 133
# ---------------------Step 34--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 108.4585132109952
# fundamental_value_0: 119.30436453209472
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 90.0384952282897
# fundamental_value_1: 99.04234475111868
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 1.8480572100000003
# prev_fundamental_value_2: 108.51942790000001
# fundamental_value_2: 110.36748511000002
# Step 34: New Price = 73.99999999999999
# Step 34: Demand = 0, Supply = 400
# ---------------------Step 35--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 119.30436453209472
# fundamental_value_0: 119.30436453209472
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 99.04234475111868
# fundamental_value_1: 99.04234475111868
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.6632514890000003
# prev_fundamental_value_2: 110.36748511000002
# fundamental_value_2: 112.03073659900002
# Step 35: New Price = 113.99999999999999
# Step 35: Demand = 400, Supply = 0
# ---------------------Step 36--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 119.30436453209472
# fundamental_value_0: 119.30436453209472
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 99.04234475111868
# fundamental_value_1: 99.04234475111868
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.4969263401000001
# prev_fundamental_value_2: 112.03073659900002
# fundamental_value_2: 113.52766293910003
# Step 36: New Price = 100.79999999999998
# Step 36: Demand = 134, Supply = 266
# ---------------------Step 37--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 119.30436453209472
# fundamental_value_0: 119.30436453209472
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 99.04234475111868
# fundamental_value_1: 99.04234475111868
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.0334231100000002
# prev_fundamental_value_2: 113.52766293910003
# fundamental_value_2: 114.56108604910003
# Step 37: New Price = 114.19999999999999
# Step 37: Demand = 267, Supply = 133
# ---------------------Step 38--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 119.30436453209472
# fundamental_value_0: 119.30436453209472
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 99.04234475111868
# fundamental_value_1: 99.04234475111868
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.9300807990000002
# prev_fundamental_value_2: 114.56108604910003
# fundamental_value_2: 115.49116684810002
# Step 38: New Price = 127.6
# Step 38: Demand = 267, Supply = 133
# ---------------------Step 39--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 119.30436453209472
# fundamental_value_0: 131.2348009853042
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 99.04234475111868
# fundamental_value_1: 108.94657922623054
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 1.7370727191
# prev_fundamental_value_2: 115.49116684810002
# fundamental_value_2: 117.22823956720002
# Step 39: New Price = 87.6
# Step 39: Demand = 0, Supply = 400
# ---------------------Step 40--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 131.2348009853042
# fundamental_value_0: 118.11132088677377
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 108.94657922623054
# fundamental_value_1: 95.87298971908288
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: 0.3495548511000001
# prev_fundamental_value_2: 117.22823956720002
# fundamental_value_2: 117.57779441830002
# Step 40: New Price = 127.6
# Step 40: Demand = 400, Supply = 0
# ---------------------Step 41--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 118.11132088677377
# fundamental_value_0: 118.11132088677377
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 95.87298971908288
# fundamental_value_1: 95.87298971908288
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.0007887699000000414
# prev_fundamental_value_2: 117.57779441830002
# fundamental_value_2: 117.57858318820001
# Step 41: New Price = 87.6
# Step 41: Demand = 0, Supply = 400
# ---------------------Step 42--------------
# Haber/Bilgi_0: -2
# Haber/Bilgi_0 - Değeri: -0.2
# prev_fundamental_value_0: 118.11132088677377
# fundamental_value_0: 94.48905670941902
# Haber/Bilgi_1: -2
# Haber/Bilgi_1 - Değeri: -0.24
# prev_fundamental_value_1: 95.87298971908288
# fundamental_value_1: 72.86347218650299
# Haber/Bilgi_2: -2
# Haber/Bilgi_2 - Değeri: -1.4854795109999999
# prev_fundamental_value_2: 117.57858318820001
# fundamental_value_2: 116.09310367720002
# Step 42: New Price = 127.6
# Step 42: Demand = 400, Supply = 0
# ---------------------Step 43--------------
# Haber/Bilgi_0: 2
# Haber/Bilgi_0 - Değeri: 0.2
# prev_fundamental_value_0: 94.48905670941902
# fundamental_value_0: 113.38686805130283
# Haber/Bilgi_1: 2
# Haber/Bilgi_1 - Değeri: 0.2
# prev_fundamental_value_1: 72.86347218650299
# fundamental_value_1: 87.43616662380359
# Haber/Bilgi_2: 2
# Haber/Bilgi_2 - Değeri: 0.4630684401000001
# prev_fundamental_value_2: 116.09310367720002
# fundamental_value_2: 116.55617211730002
# Step 43: New Price = 87.6
# Step 43: Demand = 0, Supply = 400
# ---------------------Step 44--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 113.38686805130283
# fundamental_value_0: 124.7255548564331
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 87.43616662380359
# fundamental_value_1: 96.17978328618395
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 1.002951
# prev_fundamental_value_2: 116.55617211730002
# fundamental_value_2: 117.55912311730002
# Step 44: New Price = 101.0
# Step 44: Demand = 267, Supply = 133
# ---------------------Step 45--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 124.7255548564331
# fundamental_value_0: 112.2529993707898
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 96.17978328618395
# fundamental_value_1: 84.63820929184187
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: 0.002655900000000322
# prev_fundamental_value_2: 117.55912311730002
# fundamental_value_2: 117.56177901730001
# Step 45: New Price = 114.4
# Step 45: Demand = 267, Supply = 133
# ---------------------Step 46--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 112.2529993707898
# fundamental_value_0: 112.2529993707898
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 84.63820929184187
# fundamental_value_1: 84.63820929184187
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.002390309999999951
# prev_fundamental_value_2: 117.56177901730001
# fundamental_value_2: 117.56416932730001
# Step 46: New Price = 101.0
# Step 46: Demand = 133, Supply = 267
# ---------------------Step 47--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 112.2529993707898
# fundamental_value_0: 112.2529993707898
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 84.63820929184187
# fundamental_value_1: 84.63820929184187
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.0021512790000000614
# prev_fundamental_value_2: 117.56416932730001
# fundamental_value_2: 117.56632060630001
# Step 47: New Price = 114.4
# Step 47: Demand = 267, Supply = 133
# ---------------------Step 48--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 112.2529993707898
# fundamental_value_0: 112.2529993707898
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 84.63820929184187
# fundamental_value_1: 84.63820929184187
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.0019361511000000053
# prev_fundamental_value_2: 117.56632060630001
# fundamental_value_2: 117.56825675740001
# Step 48: New Price = 101.0
# Step 48: Demand = 133, Supply = 267
# ---------------------Step 49--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 112.2529993707898
# fundamental_value_0: 123.47829930786878
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 84.63820929184187
# fundamental_value_1: 93.10203022102607
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 0.5879319399
# prev_fundamental_value_2: 117.56825675740001
# fundamental_value_2: 118.15618869730001
# Step 49: New Price = 114.4
# Step 49: Demand = 267, Supply = 133
# ---------------------Step 50--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 123.47829930786878
# fundamental_value_0: 123.47829930786878
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 93.10203022102607
# fundamental_value_1: 93.10203022102607
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.8429493420000002
# prev_fundamental_value_2: 118.15618869730001
# fundamental_value_2: 118.99913803930001
# Step 50: New Price = 127.80000000000001
# Step 50: Demand = 267, Supply = 133
# ---------------------Step 51--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 123.47829930786878
# fundamental_value_0: 111.13046937708191
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 93.10203022102607
# fundamental_value_1: 81.92978659450294
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -0.14134559219999987
# prev_fundamental_value_2: 118.99913803930001
# fundamental_value_2: 118.85779244710001
# Step 51: New Price = 87.80000000000001
# Step 51: Demand = 0, Supply = 400
# ---------------------Step 52--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 111.13046937708191
# fundamental_value_0: 122.2435163147901
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 81.92978659450294
# fundamental_value_1: 90.12276525395323
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 1.4004101592000002
# prev_fundamental_value_2: 118.85779244710001
# fundamental_value_2: 120.25820260630002
# Step 52: New Price = 101.20000000000002
# Step 52: Demand = 267, Supply = 133
# ---------------------Step 53--------------
# Haber/Bilgi_0: 2
# Haber/Bilgi_0 - Değeri: 0.2
# prev_fundamental_value_0: 122.2435163147901
# fundamental_value_0: 146.69221957774812
# Haber/Bilgi_1: 2
# Haber/Bilgi_1 - Değeri: 0.2
# prev_fundamental_value_1: 90.12276525395323
# fundamental_value_1: 108.14731830474388
# Haber/Bilgi_2: 2
# Haber/Bilgi_2 - Değeri: 2.4327479511
# prev_fundamental_value_2: 120.25820260630002
# fundamental_value_2: 122.69095055740001
# Step 53: New Price = 114.60000000000002
# Step 53: Demand = 267, Supply = 133
# ---------------------Step 54--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 146.69221957774812
# fundamental_value_0: 146.69221957774812
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 108.14731830474388
# fundamental_value_1: 108.14731830474388
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.8756625599000003
# prev_fundamental_value_2: 122.69095055740001
# fundamental_value_2: 124.56661311730002
# Step 54: New Price = 128.00000000000003
# Step 54: Demand = 267, Supply = 133
# ---------------------Step 55--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 146.69221957774812
# fundamental_value_0: 146.69221957774812
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 108.14731830474388
# fundamental_value_1: 108.14731830474388
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 2.0019069000000003
# prev_fundamental_value_2: 124.56661311730002
# fundamental_value_2: 126.56852001730002
# Step 55: New Price = 114.80000000000003
# Step 55: Demand = 134, Supply = 266
# ---------------------Step 56--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 146.69221957774812
# fundamental_value_0: 161.36144153552294
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 108.14731830474388
# fundamental_value_1: 118.96205013521826
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 2.7017162100000003
# prev_fundamental_value_2: 126.56852001730002
# fundamental_value_2: 129.27023622730002
# Step 56: New Price = 128.20000000000002
# Step 56: Demand = 267, Supply = 133
# ---------------------Step 57--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 161.36144153552294
# fundamental_value_0: 177.49758568907524
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 118.96205013521826
# fundamental_value_1: 130.85825514874008
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 3.331544589
# prev_fundamental_value_2: 129.27023622730002
# fundamental_value_2: 132.60178081630002
# Step 57: New Price = 141.60000000000002
# Step 57: Demand = 267, Supply = 133
# ---------------------Step 58--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 177.49758568907524
# fundamental_value_0: 195.24734425798277
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 130.85825514874008
# fundamental_value_1: 143.9440806636141
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 3.8983901301
# prev_fundamental_value_2: 132.60178081630002
# fundamental_value_2: 136.50017094640003
# Step 58: New Price = 128.40000000000003
# Step 58: Demand = 134, Supply = 266
# ---------------------Step 59--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 195.24734425798277
# fundamental_value_0: 195.24734425798277
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 143.9440806636141
# fundamental_value_1: 143.9440806636141
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 3.1947405210000004
# prev_fundamental_value_2: 136.50017094640003
# fundamental_value_2: 139.69491146740003
# Step 59: New Price = 168.40000000000003
# Step 59: Demand = 400, Supply = 0
# ---------------------Step 60--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 195.24734425798277
# fundamental_value_0: 195.24734425798277
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 143.9440806636141
# fundamental_value_1: 143.9440806636141
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 2.8752664689
# prev_fundamental_value_2: 139.69491146740003
# fundamental_value_2: 142.57017793630004
# Step 60: New Price = 155.20000000000005
# Step 60: Demand = 134, Supply = 266
# ---------------------Step 61--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 195.24734425798277
# fundamental_value_0: 175.7226098321845
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 143.9440806636141
# fundamental_value_1: 126.67079098398041
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: 2.0015504181000003
# prev_fundamental_value_2: 142.57017793630004
# fundamental_value_2: 144.57172835440005
# Step 61: New Price = 142.00000000000006
# Step 61: Demand = 134, Supply = 266
# ---------------------Step 62--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 175.7226098321845
# fundamental_value_0: 193.29487081540296
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 126.67079098398041
# fundamental_value_1: 139.33787008237846
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 2.3875847802000005
# prev_fundamental_value_2: 144.57172835440005
# fundamental_value_2: 146.95931313460005
# Step 62: New Price = 155.40000000000006
# Step 62: Demand = 267, Supply = 133
# ---------------------Step 63--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 193.29487081540296
# fundamental_value_0: 193.29487081540296
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 139.33787008237846
# fundamental_value_1: 139.33787008237846
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.5212051100000004
# prev_fundamental_value_2: 146.95931313460005
# fundamental_value_2: 148.48051824460006
# Step 63: New Price = 142.20000000000007
# Step 63: Demand = 134, Supply = 266
# ---------------------Step 64--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 193.29487081540296
# fundamental_value_0: 193.29487081540296
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 139.33787008237846
# fundamental_value_1: 139.33787008237846
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.3690845990000002
# prev_fundamental_value_2: 148.48051824460006
# fundamental_value_2: 149.84960284360005
# Step 64: New Price = 155.60000000000008
# Step 64: Demand = 267, Supply = 133
# ---------------------Step 65--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 193.29487081540296
# fundamental_value_0: 193.29487081540296
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 139.33787008237846
# fundamental_value_1: 139.33787008237846
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.2321761391000001
# prev_fundamental_value_2: 149.84960284360005
# fundamental_value_2: 151.08177898270006
# Step 65: New Price = 142.4000000000001
# Step 65: Demand = 134, Supply = 266
# ---------------------Step 66--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 193.29487081540296
# fundamental_value_0: 173.96538373386267
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 139.33787008237846
# fundamental_value_1: 122.61732567249305
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -0.10485207089999982
# prev_fundamental_value_2: 151.08177898270006
# fundamental_value_2: 150.97692691180006
# Step 66: New Price = 155.8000000000001
# Step 66: Demand = 267, Supply = 133
# ---------------------Step 67--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 173.96538373386267
# fundamental_value_0: 156.5688453604764
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 122.61732567249305
# fundamental_value_1: 107.90324659179389
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -1.3081774599
# prev_fundamental_value_2: 150.97692691180006
# fundamental_value_2: 149.66874945190006
# Step 67: New Price = 142.6000000000001
# Step 67: Demand = 134, Supply = 266
# ---------------------Step 68--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 156.5688453604764
# fundamental_value_0: 156.5688453604764
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 107.90324659179389
# fundamental_value_1: 107.90324659179389
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.4911703100000002
# prev_fundamental_value_2: 149.66874945190006
# fundamental_value_2: 148.17757914190005
# Step 68: New Price = 156.0000000000001
# Step 68: Demand = 267, Supply = 133
# ---------------------Step 69--------------
# Haber/Bilgi_0: -2
# Haber/Bilgi_0 - Değeri: -0.2
# prev_fundamental_value_0: 156.5688453604764
# fundamental_value_0: 125.2550762883811
# Haber/Bilgi_1: -2
# Haber/Bilgi_1 - Değeri: -0.24
# prev_fundamental_value_1: 107.90324659179389
# fundamental_value_1: 82.00646740976336
# Haber/Bilgi_2: -2
# Haber/Bilgi_2 - Değeri: -3.1420532789999998
# prev_fundamental_value_2: 148.17757914190005
# fundamental_value_2: 145.03552586290004
# Step 69: New Price = 142.80000000000013
# Step 69: Demand = 134, Supply = 266
# ---------------------Step 70--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 125.2550762883811
# fundamental_value_0: 125.2550762883811
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 82.00646740976336
# fundamental_value_1: 82.00646740976336
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -2.8278479511
# prev_fundamental_value_2: 145.03552586290004
# fundamental_value_2: 142.20767791180003
# Step 70: New Price = 129.40000000000012
# Step 70: Demand = 133, Supply = 267
# ---------------------Step 71--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 125.2550762883811
# fundamental_value_0: 125.2550762883811
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 82.00646740976336
# fundamental_value_1: 82.00646740976336
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -2.2312525599
# prev_fundamental_value_2: 142.20767791180003
# fundamental_value_2: 139.97642535190002
# Step 71: New Price = 116.00000000000011
# Step 71: Demand = 133, Supply = 267
# ---------------------Step 72--------------
# Haber/Bilgi_0: 2
# Haber/Bilgi_0 - Değeri: 0.2
# prev_fundamental_value_0: 125.2550762883811
# fundamental_value_0: 150.30609154605733
# Haber/Bilgi_1: 2
# Haber/Bilgi_1 - Değeri: 0.2
# prev_fundamental_value_1: 82.00646740976336
# fundamental_value_1: 98.40776089171604
# Haber/Bilgi_2: 2
# Haber/Bilgi_2 - Değeri: -0.5219379000000002
# prev_fundamental_value_2: 139.97642535190002
# fundamental_value_2: 139.4544874519
# Step 72: New Price = 129.40000000000012
# Step 72: Demand = 267, Supply = 133
# ---------------------Step 73--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 150.30609154605733
# fundamental_value_0: 150.30609154605733
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 98.40776089171604
# fundamental_value_1: 98.40776089171604
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -0.4697441100000002
# prev_fundamental_value_2: 139.4544874519
# fundamental_value_2: 138.9847433419
# Step 73: New Price = 142.80000000000013
# Step 73: Demand = 267, Supply = 133
# ---------------------Step 74--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 150.30609154605733
# fundamental_value_0: 135.2754823914516
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 98.40776089171604
# fundamental_value_1: 86.59882958471012
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -1.3227696990000002
# prev_fundamental_value_2: 138.9847433419
# fundamental_value_2: 137.66197364290002
# Step 74: New Price = 129.60000000000014
# Step 74: Demand = 134, Supply = 266
# ---------------------Step 75--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 135.2754823914516
# fundamental_value_0: 148.80303063059674
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 86.59882958471012
# fundamental_value_1: 95.25871254318113
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: -0.29049272910000024
# prev_fundamental_value_2: 137.66197364290002
# fundamental_value_2: 137.3714809138
# Step 75: New Price = 143.00000000000014
# Step 75: Demand = 267, Supply = 133
# ---------------------Step 76--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 148.80303063059674
# fundamental_value_0: 133.92272756753707
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 95.25871254318113
# fundamental_value_1: 83.82766703799939
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -0.8476328601000003
# prev_fundamental_value_2: 137.3714809138
# fundamental_value_2: 136.52384805370002
# Step 76: New Price = 129.80000000000015
# Step 76: Demand = 134, Supply = 266
# ---------------------Step 77--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 133.92272756753707
# fundamental_value_0: 147.31500032429076
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 83.82766703799939
# fundamental_value_1: 92.21043374179933
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 0.45094102199999997
# prev_fundamental_value_2: 136.52384805370002
# fundamental_value_2: 136.97478907570002
# Step 77: New Price = 143.20000000000016
# Step 77: Demand = 267, Supply = 133
# ---------------------Step 78--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 147.31500032429076
# fundamental_value_0: 132.5835002918617
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 92.21043374179933
# fundamental_value_1: 81.14518169278341
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -0.49415308020000015
# prev_fundamental_value_2: 136.97478907570002
# fundamental_value_2: 136.48063599550002
# Step 78: New Price = 130.00000000000017
# Step 78: Demand = 134, Supply = 266
# ---------------------Step 79--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 132.5835002918617
# fundamental_value_0: 132.5835002918617
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 81.14518169278341
# fundamental_value_1: 81.14518169278341
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.18288342000000024
# prev_fundamental_value_2: 136.48063599550002
# fundamental_value_2: 136.66351941550002
# Step 79: New Price = 143.40000000000018
# Step 79: Demand = 267, Supply = 133
# ---------------------Step 80--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 132.5835002918617
# fundamental_value_0: 119.32515026267552
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 81.14518169278341
# fundamental_value_1: 71.4077598896494
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -0.735404922
# prev_fundamental_value_2: 136.66351941550002
# fundamental_value_2: 135.92811449350003
# Step 80: New Price = 103.40000000000018
# Step 80: Demand = 0, Supply = 400
# ---------------------Step 81--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 119.32515026267552
# fundamental_value_0: 107.39263523640797
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 71.4077598896494
# fundamental_value_1: 62.83882870289147
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -1.5618644298
# prev_fundamental_value_2: 135.92811449350003
# fundamental_value_2: 134.36625006370002
# Step 81: New Price = 116.80000000000018
# Step 81: Demand = 267, Supply = 133
# ---------------------Step 82--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 107.39263523640797
# fundamental_value_0: 118.13189876004877
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 62.83882870289147
# fundamental_value_1: 69.12271157318062
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: -1.1332991790000002
# prev_fundamental_value_2: 134.36625006370002
# fundamental_value_2: 133.23295088470002
# Step 82: New Price = 103.40000000000018
# Step 82: Demand = 133, Supply = 267
# ---------------------Step 83--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 118.13189876004877
# fundamental_value_0: 106.3187088840439
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 69.12271157318062
# fundamental_value_1: 60.82798618439895
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -1.9199692611000003
# prev_fundamental_value_2: 133.23295088470002
# fundamental_value_2: 131.31298162360002
# Step 83: New Price = 116.80000000000018
# Step 83: Demand = 267, Supply = 133
# ---------------------Step 84--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 106.3187088840439
# fundamental_value_0: 116.9505797724483
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 60.82798618439895
# fundamental_value_1: 66.91078480283885
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: -0.5141617388999999
# prev_fundamental_value_2: 131.31298162360002
# fundamental_value_2: 130.79881988470004
# Step 84: New Price = 103.40000000000018
# Step 84: Demand = 133, Supply = 267
# ---------------------Step 85--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 116.9505797724483
# fundamental_value_0: 116.9505797724483
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 66.91078480283885
# fundamental_value_1: 66.91078480283885
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -0.7765561611000003
# prev_fundamental_value_2: 130.79881988470004
# fundamental_value_2: 130.02226372360005
# Step 85: New Price = 116.80000000000018
# Step 85: Demand = 267, Supply = 133
# ---------------------Step 86--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 116.9505797724483
# fundamental_value_0: 105.25552179520346
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 66.91078480283885
# fundamental_value_1: 58.881490626498184
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -1.2850899489
# prev_fundamental_value_2: 130.02226372360005
# fundamental_value_2: 128.73717377470004
# Step 86: New Price = 130.2000000000002
# Step 86: Demand = 267, Supply = 133
# ---------------------Step 87--------------
# Haber/Bilgi_0: -2
# Haber/Bilgi_0 - Değeri: -0.2
# prev_fundamental_value_0: 105.25552179520346
# fundamental_value_0: 84.20441743616277
# Haber/Bilgi_1: -2
# Haber/Bilgi_1 - Değeri: -0.24
# prev_fundamental_value_1: 58.881490626498184
# fundamental_value_1: 44.74993287613862
# Haber/Bilgi_2: -2
# Haber/Bilgi_2 - Değeri: -3.2703915501000007
# prev_fundamental_value_2: 128.73717377470004
# fundamental_value_2: 125.46678222460004
# Step 87: New Price = 90.20000000000019
# Step 87: Demand = 0, Supply = 400
# ---------------------Step 88--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 84.20441743616277
# fundamental_value_0: 84.20441743616277
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 44.74993287613862
# fundamental_value_1: 44.74993287613862
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -2.6295417990000005
# prev_fundamental_value_2: 125.46678222460004
# fundamental_value_2: 122.83724042560004
# Step 88: New Price = 76.80000000000018
# Step 88: Demand = 133, Supply = 267
# ---------------------Step 89--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 84.20441743616277
# fundamental_value_0: 84.20441743616277
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 44.74993287613862
# fundamental_value_1: 44.74993287613862
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -2.3665876191
# prev_fundamental_value_2: 122.83724042560004
# fundamental_value_2: 120.47065280650004
# Step 89: New Price = 90.20000000000019
# Step 89: Demand = 267, Supply = 133
# ---------------------Step 90--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 84.20441743616277
# fundamental_value_0: 84.20441743616277
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 44.74993287613862
# fundamental_value_1: 44.74993287613862
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.8161182611000002
# prev_fundamental_value_2: 120.47065280650004
# fundamental_value_2: 118.65453454540004
# Step 90: New Price = 76.80000000000018
# Step 90: Demand = 133, Supply = 267
# ---------------------Step 91--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 84.20441743616277
# fundamental_value_0: 84.20441743616277
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 44.74993287613862
# fundamental_value_1: 44.74993287613862
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.3206958389000003
# prev_fundamental_value_2: 118.65453454540004
# fundamental_value_2: 117.33383870650005
# Step 91: New Price = 90.20000000000019
# Step 91: Demand = 267, Supply = 133
# ---------------------Step 92--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 84.20441743616277
# fundamental_value_0: 84.20441743616277
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 44.74993287613862
# fundamental_value_1: 44.74993287613862
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.5024368511000001
# prev_fundamental_value_2: 117.33383870650005
# fundamental_value_2: 115.83140185540005
# Step 92: New Price = 76.80000000000018
# Step 92: Demand = 133, Supply = 267
# ---------------------Step 93--------------
# Haber/Bilgi_0: -2
# Haber/Bilgi_0 - Değeri: -0.2
# prev_fundamental_value_0: 84.20441743616277
# fundamental_value_0: 67.36353394893021
# Haber/Bilgi_1: -2
# Haber/Bilgi_1 - Değeri: -0.24
# prev_fundamental_value_1: 44.74993287613862
# fundamental_value_1: 34.00994898586535
# Haber/Bilgi_2: -2
# Haber/Bilgi_2 - Değeri: -2.8383825699000003
# prev_fundamental_value_2: 115.83140185540005
# fundamental_value_2: 112.99301928550004
# Step 93: New Price = 90.20000000000019
# Step 93: Demand = 267, Supply = 133
# ---------------------Step 94--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 67.36353394893021
# fundamental_value_0: 74.09988734382323
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 34.00994898586535
# fundamental_value_1: 37.41094388445188
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: -1.9683549090000003
# prev_fundamental_value_2: 112.99301928550004
# fundamental_value_2: 111.02466437650004
# Step 94: New Price = 76.80000000000018
# Step 94: Demand = 133, Supply = 267
# ---------------------Step 95--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 74.09988734382323
# fundamental_value_0: 74.09988734382323
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 37.41094388445188
# fundamental_value_1: 37.41094388445188
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.7715194181000005
# prev_fundamental_value_2: 111.02466437650004
# fundamental_value_2: 109.25314495840004
# Step 95: New Price = 63.40000000000018
# Step 95: Demand = 133, Supply = 267
# ---------------------Step 96--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 74.09988734382323
# fundamental_value_0: 81.50987607820555
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 37.41094388445188
# ...
# prev_fundamental_value_1: 0.22142090474891551
# fundamental_value_1: 0.19485039617904565
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -1.0009737899999998
# prev_fundamental_value_2: 48.252691548100124
# fundamental_value_2: 47.25171775810013
# Step 469: New Price = 1
# Step 469: Demand = 133, Supply = 267
# ---------------------Step 470--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.848105785371908
# fundamental_value_0: 5.848105785371908
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.19485039617904565
# fundamental_value_1: 0.19485039617904565
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -0.900876411
# prev_fundamental_value_2: 47.25171775810013
# fundamental_value_2: 46.35084134710013
# Step 470: New Price = 14.4
# Step 470: Demand = 267, Supply = 133
# ---------------------Step 471--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.848105785371908
# fundamental_value_0: 5.848105785371908
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.19485039617904565
# fundamental_value_1: 0.19485039617904565
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -0.8107887699000003
# prev_fundamental_value_2: 46.35084134710013
# fundamental_value_2: 45.54005257720013
# Step 471: New Price = 1
# Step 471: Demand = 133, Supply = 267
# ---------------------Step 472--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.848105785371908
# fundamental_value_0: 5.848105785371908
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.19485039617904565
# fundamental_value_1: 0.19485039617904565
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.043520489
# prev_fundamental_value_2: 45.54005257720013
# fundamental_value_2: 44.49653208820013
# Step 472: New Price = 14.4
# Step 472: Demand = 267, Supply = 133
# ---------------------Step 473--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 5.848105785371908
# fundamental_value_0: 5.263295206834718
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 0.19485039617904565
# fundamental_value_1: 0.17146834863756016
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -1.8391684401000001
# prev_fundamental_value_2: 44.49653208820013
# fundamental_value_2: 42.65736364810012
# Step 473: New Price = 1
# Step 473: Demand = 133, Supply = 267
# ---------------------Step 474--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.263295206834718
# fundamental_value_0: 5.263295206834718
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.17146834863756016
# fundamental_value_1: 0.17146834863756016
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.341441
# prev_fundamental_value_2: 42.65736364810012
# fundamental_value_2: 41.31592264810012
# Step 474: New Price = 14.4
# Step 474: Demand = 267, Supply = 133
# ---------------------Step 475--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.263295206834718
# fundamental_value_0: 5.263295206834718
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.17146834863756016
# fundamental_value_1: 0.17146834863756016
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.2072969000000002
# prev_fundamental_value_2: 41.31592264810012
# fundamental_value_2: 40.10862574810012
# Step 475: New Price = 1
# Step 475: Demand = 133, Supply = 267
# ---------------------Step 476--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.263295206834718
# fundamental_value_0: 5.263295206834718
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.17146834863756016
# fundamental_value_1: 0.17146834863756016
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.0865672100000001
# prev_fundamental_value_2: 40.10862574810012
# fundamental_value_2: 39.02205853810012
# Step 476: New Price = 14.4
# Step 476: Demand = 267, Supply = 133
# ---------------------Step 477--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.263295206834718
# fundamental_value_0: 5.263295206834718
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.17146834863756016
# fundamental_value_1: 0.17146834863756016
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -0.9779104890000001
# prev_fundamental_value_2: 39.02205853810012
# fundamental_value_2: 38.044148049100116
# Step 477: New Price = 1
# Step 477: Demand = 133, Supply = 267
# ---------------------Step 478--------------
# Haber/Bilgi_0: -1
# Haber/Bilgi_0 - Değeri: -0.1
# prev_fundamental_value_0: 5.263295206834718
# fundamental_value_0: 4.736965686151246
# Haber/Bilgi_1: -1
# Haber/Bilgi_1 - Değeri: -0.12
# prev_fundamental_value_1: 0.17146834863756016
# fundamental_value_1: 0.15089214680105295
# Haber/Bilgi_2: -1
# Haber/Bilgi_2 - Değeri: -1.7801194401
# prev_fundamental_value_2: 38.044148049100116
# fundamental_value_2: 36.264028609000114
# Step 478: New Price = 14.4
# Step 478: Demand = 267, Supply = 133
# ---------------------Step 479--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 4.736965686151246
# fundamental_value_0: 4.736965686151246
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.15089214680105295
# fundamental_value_1: 0.15089214680105295
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.2882969000000002
# prev_fundamental_value_2: 36.264028609000114
# fundamental_value_2: 34.975731709000115
# Step 479: New Price = 1
# Step 479: Demand = 133, Supply = 267
# ---------------------Step 480--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 4.736965686151246
# fundamental_value_0: 4.736965686151246
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.15089214680105295
# fundamental_value_1: 0.15089214680105295
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.1594672100000003
# prev_fundamental_value_2: 34.975731709000115
# fundamental_value_2: 33.81626449900011
# Step 480: New Price = 14.4
# Step 480: Demand = 267, Supply = 133
# ---------------------Step 481--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 4.736965686151246
# fundamental_value_0: 4.736965686151246
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.15089214680105295
# fundamental_value_1: 0.15089214680105295
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.043520489
# prev_fundamental_value_2: 33.81626449900011
# fundamental_value_2: 32.77274401000011
# Step 481: New Price = 1
# Step 481: Demand = 133, Supply = 267
# ---------------------Step 482--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 4.736965686151246
# fundamental_value_0: 4.736965686151246
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.15089214680105295
# fundamental_value_1: 0.15089214680105295
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -0.9391684401000002
# prev_fundamental_value_2: 32.77274401000011
# fundamental_value_2: 31.83357556990011
# Step 482: New Price = 14.4
# Step 482: Demand = 267, Supply = 133
# ---------------------Step 483--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 4.736965686151246
# fundamental_value_0: 5.21066225476637
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 0.15089214680105295
# fundamental_value_1: 0.16598136148115825
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 0.36855899999999997
# prev_fundamental_value_2: 31.83357556990011
# fundamental_value_2: 32.20213456990011
# Step 483: New Price = 1
# Step 483: Demand = 133, Supply = 267
# ---------------------Step 484--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.21066225476637
# fundamental_value_0: 5.21066225476637
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.16598136148115825
# fundamental_value_1: 0.16598136148115825
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.3317031
# prev_fundamental_value_2: 32.20213456990011
# fundamental_value_2: 32.53383766990011
# Step 484: New Price = 14.4
# Step 484: Demand = 267, Supply = 133
# ---------------------Step 485--------------
# Haber/Bilgi_0: -2
# Haber/Bilgi_0 - Değeri: -0.2
# prev_fundamental_value_0: 5.21066225476637
# fundamental_value_0: 4.168529803813096
# Haber/Bilgi_1: -2
# Haber/Bilgi_1 - Değeri: -0.24
# prev_fundamental_value_1: 0.16598136148115825
# fundamental_value_1: 0.12614583472568028
# Haber/Bilgi_2: -2
# Haber/Bilgi_2 - Değeri: -1.50146721
# prev_fundamental_value_2: 32.53383766990011
# fundamental_value_2: 31.032370459900108
# Step 485: New Price = 1
# Step 485: Demand = 133, Supply = 267
# ---------------------Step 486--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 4.168529803813096
# fundamental_value_0: 4.168529803813096
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.12614583472568028
# fundamental_value_1: 0.12614583472568028
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.3513204890000001
# prev_fundamental_value_2: 31.032370459900108
# fundamental_value_2: 29.68104997090011
# Step 486: New Price = 14.4
# Step 486: Demand = 267, Supply = 133
# ---------------------Step 487--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 4.168529803813096
# fundamental_value_0: 4.168529803813096
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.12614583472568028
# fundamental_value_1: 0.12614583472568028
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.2161884401000003
# prev_fundamental_value_2: 29.68104997090011
# fundamental_value_2: 28.464861530800107
# Step 487: New Price = 1
# Step 487: Demand = 133, Supply = 267
# ---------------------Step 488--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 4.168529803813096
# fundamental_value_0: 4.5853827841944055
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 0.12614583472568028
# fundamental_value_1: 0.1387604181982483
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 0.11924100000000004
# prev_fundamental_value_2: 28.464861530800107
# fundamental_value_2: 28.584102530800106
# Step 488: New Price = 14.4
# Step 488: Demand = 267, Supply = 133
# ---------------------Step 489--------------
# Haber/Bilgi_0: -2
# Haber/Bilgi_0 - Değeri: -0.2
# prev_fundamental_value_0: 4.5853827841944055
# fundamental_value_0: 3.6683062273555245
# Haber/Bilgi_1: -2
# Haber/Bilgi_1 - Değeri: -0.24
# prev_fundamental_value_1: 0.1387604181982483
# fundamental_value_1: 0.10545791783066871
# Haber/Bilgi_2: -2
# Haber/Bilgi_2 - Değeri: -1.6926831
# prev_fundamental_value_2: 28.584102530800106
# fundamental_value_2: 26.891419430800106
# Step 489: New Price = 1
# Step 489: Demand = 133, Supply = 267
# ---------------------Step 490--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 3.6683062273555245
# fundamental_value_0: 3.6683062273555245
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.10545791783066871
# fundamental_value_1: 0.10545791783066871
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: -1.52341479
# prev_fundamental_value_2: 26.891419430800106
# fundamental_value_2: 25.368004640800105
# Step 490: New Price = 14.4
# Step 490: Demand = 267, Supply = 133
# ---------------------Step 491--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 3.6683062273555245
# fundamental_value_0: 4.035136850091077
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 0.10545791783066871
# fundamental_value_1: 0.11600370961373559
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: -0.4710733110000002
# prev_fundamental_value_2: 25.368004640800105
# fundamental_value_2: 24.896931329800104
# Step 491: New Price = 1
# Step 491: Demand = 133, Supply = 267
# ---------------------Step 492--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 4.035136850091077
# fundamental_value_0: 4.438650535100185
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 0.11600370961373559
# fundamental_value_1: 0.12760408057510914
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 0.4760340200999999
# prev_fundamental_value_2: 24.896931329800104
# fundamental_value_2: 25.372965349900102
# Step 492: New Price = 14.4
# Step 492: Demand = 267, Supply = 133
# ---------------------Step 493--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 4.438650535100185
# fundamental_value_0: 4.882515588610203
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 0.12760408057510914
# fundamental_value_1: 0.14036448863262005
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 1.014620022
# prev_fundamental_value_2: 25.372965349900102
# fundamental_value_2: 26.3875853719001
# Step 493: New Price = 1
# Step 493: Demand = 133, Supply = 267
# ---------------------Step 494--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 4.882515588610203
# fundamental_value_0: 4.882515588610203
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.14036448863262005
# fundamental_value_1: 0.14036448863262005
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 0.9131580197999999
# prev_fundamental_value_2: 26.3875853719001
# fundamental_value_2: 27.300743391700102
# Step 494: New Price = 14.4
# Step 494: Demand = 267, Supply = 133
# ---------------------Step 495--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 4.882515588610203
# fundamental_value_0: 5.3707671474712235
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 0.14036448863262005
# fundamental_value_1: 0.15440093749588205
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 2.34946341
# prev_fundamental_value_2: 27.300743391700102
# fundamental_value_2: 29.6502068017001
# Step 495: New Price = 1
# Step 495: Demand = 133, Supply = 267
# ---------------------Step 496--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.3707671474712235
# fundamental_value_0: 5.3707671474712235
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.15440093749588205
# fundamental_value_1: 0.15440093749588205
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 2.1145170689999997
# prev_fundamental_value_2: 29.6502068017001
# fundamental_value_2: 31.764723870700102
# Step 496: New Price = 14.4
# Step 496: Demand = 267, Supply = 133
# ---------------------Step 497--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.3707671474712235
# fundamental_value_0: 5.3707671474712235
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.15440093749588205
# fundamental_value_1: 0.15440093749588205
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.9030653621
# prev_fundamental_value_2: 31.764723870700102
# fundamental_value_2: 33.667789232800104
# Step 497: New Price = 1
# Step 497: Demand = 133, Supply = 267
# ---------------------Step 498--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.3707671474712235
# fundamental_value_0: 5.3707671474712235
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.15440093749588205
# fundamental_value_1: 0.15440093749588205
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.3989482298000002
# prev_fundamental_value_2: 33.667789232800104
# fundamental_value_2: 35.0667374626001
# Step 498: New Price = 14.4
# Step 498: Demand = 267, Supply = 133
# ---------------------Step 499--------------
# Haber/Bilgi_0: 0
# Haber/Bilgi_0 - Değeri: 0
# prev_fundamental_value_0: 5.3707671474712235
# fundamental_value_0: 5.3707671474712235
# Haber/Bilgi_1: 0
# Haber/Bilgi_1 - Değeri: 0
# prev_fundamental_value_1: 0.15440093749588205
# fundamental_value_1: 0.15440093749588205
# Haber/Bilgi_2: 0
# Haber/Bilgi_2 - Değeri: 1.8866745990000005
# prev_fundamental_value_2: 35.0667374626001
# fundamental_value_2: 36.953412061600105
# Step 499: New Price = 1
# Step 499: Demand = 133, Supply = 267
# ---------------------Step 500--------------
# Haber/Bilgi_0: 1
# Haber/Bilgi_0 - Değeri: 0.1
# prev_fundamental_value_0: 5.3707671474712235
# fundamental_value_0: 5.907843862218346
# Haber/Bilgi_1: 1
# Haber/Bilgi_1 - Değeri: 0.1
# prev_fundamental_value_1: 0.15440093749588205
# fundamental_value_1: 0.16984103124547026
# Haber/Bilgi_2: 1
# Haber/Bilgi_2 - Değeri: 2.5980071391000004
# prev_fundamental_value_2: 36.953412061600105
# fundamental_value_2: 39.5514192007001
# Step 500: New Price = 14.4
# Step 500: Demand = 267, Supply = 133

# %% [markdown]
# **ÖNEMLİ GRAFİKLER**
#
# temel 0: kırmızı-temel tepki
#
# temel 1: yeşil - asimetriik tepki
#
# temel 2: turuncu - güçlenen tepki
#
# temel 3: mor - sönümlü tepki

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

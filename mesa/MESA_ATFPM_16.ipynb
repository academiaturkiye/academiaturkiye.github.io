# %%
# Mesa Sürümünü Değiştirme
# !pip install mesa==3.1.5
# Out:
# Collecting mesa==3.1.5
#   Downloading mesa-3.1.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mesa==3.1.5) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from mesa==3.1.5) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mesa==3.1.5) (1.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mesa==3.1.5) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->mesa==3.1.5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->mesa==3.1.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->mesa==3.1.5) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->mesa==3.1.5) (1.17.0)
# Downloading mesa-3.1.5-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 7.0 MB/s eta 0:00:00
# Installing collected packages: mesa
# Successfully installed mesa-3.1.5

# %%
# !pip install mesa[rec] komutu, Mesa kütüphanesini ekstra "recommended" (tavsiye edilen) bağımlılıklarla birlikte kurar. Bu, Mesa'nın temel özelliklerinin yanı sıra, gelişmiş görselleştirme ve analiz araçlarını kullanabilmek için gerekli olan ek paketleri de yükler.
# !pip install mesa[rec]
# Out:
# Requirement already satisfied: mesa[rec] in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (1.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (4.67.1)
# Requirement already satisfied: altair in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (5.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (3.10.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from mesa[rec]) (3.4.2)
# Collecting solara (from mesa[rec])
#   Downloading solara-1.44.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (1.33.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from altair->mesa[rec]) (4.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mesa[rec]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->mesa[rec]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->mesa[rec]) (2025.2)
# Collecting solara-server==1.44.1 (from solara-server[dev,starlette]==1.44.1->solara->mesa[rec])
#   Downloading solara_server-1.44.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting solara-ui==1.44.1 (from solara-ui[all]==1.44.1->solara->mesa[rec])
#   Downloading solara_ui-1.44.1-py2.py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: click>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (8.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (3.18.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (6.17.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.11/dist-packages (from solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (6.1.12)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (5.10.4)
# Collecting rich-click (from solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec])
#   Downloading rich_click-1.8.8-py3-none-any.whl.metadata (7.9 kB)
# Collecting watchdog (from solara-server[dev,starlette]==1.44.1->solara->mesa[rec])
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.1 MB/s eta 0:00:00
# Collecting watchfiles (from solara-server[dev,starlette]==1.44.1->solara->mesa[rec])
#   Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting starlette (from solara-server[dev,starlette]==1.44.1->solara->mesa[rec])
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting uvicorn (from solara-server[dev,starlette]==1.44.1->solara->mesa[rec])
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: websockets in /usr/local/lib/python3.11/dist-packages (from solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (15.0.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (4.12.2)
# Collecting ipyvue>=1.9.0 (from solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec])
#   Downloading ipyvue-1.11.2-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting ipyvuetify>=1.6.10 (from solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec])
#   Downloading ipyvuetify-1.11.1-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets>=7.7 in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (7.7.1)
# Collecting reacton>=1.9 (from solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec])
#   Downloading reacton-1.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (2.32.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.44.1->solara->mesa[rec]) (5.5.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.44.1->solara->mesa[rec]) (3.7)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from solara-ui[all]==1.44.1->solara->mesa[rec]) (2.18.0)
# Collecting pymdown-extensions (from solara-ui[all]==1.44.1->solara->mesa[rec])
#   Downloading pymdown_extensions-10.14.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair->mesa[rec]) (0.24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mesa[rec]) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair->mesa[rec]) (3.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (3.0.13)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (1.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (6.4.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (5.7.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (2.21.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from pymdown-extensions->solara-ui[all]==1.44.1->solara->mesa[rec]) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (2025.1.31)
# Requirement already satisfied: rich>=10.7 in /usr/local/lib/python3.11/dist-packages (from rich-click->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (13.9.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (4.9.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (1.3.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (3.0.50)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (4.3.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.7->rich-click->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (3.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click->solara-server==1.44.1->solara-server[dev,starlette]==1.44.1->solara->mesa[rec]) (0.1.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (23.1.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (1.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.2.13)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (1.5.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (2.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (2.22)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.7->solara-ui==1.44.1->solara-ui[all]==1.44.1->solara->mesa[rec]) (1.8.0)
# Downloading solara-1.44.1-py2.py3-none-any.whl (5.9 kB)
# Downloading solara_server-1.44.1-py2.py3-none-any.whl (3.9 kB)
# Downloading solara_ui-1.44.1-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.0 MB/s eta 0:00:00
# Downloading ipyvue-1.11.2-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 41.4 MB/s eta 0:00:00
# Downloading ipyvuetify-1.11.1-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 50.6 MB/s eta 0:00:00
# Downloading reacton-1.9.1-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 8.9 MB/s eta 0:00:00
# Downloading pymdown_extensions-10.14.3-py3-none-any.whl (264 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.5/264.5 kB 11.3 MB/s eta 0:00:00
# Downloading rich_click-1.8.8-py3-none-any.whl (35 kB)
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.3 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.6 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.8 MB/s eta 0:00:00
# Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 21.6 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 45.7 MB/s eta 0:00:00
# Installing collected packages: watchdog, uvicorn, pymdown-extensions, jedi, watchfiles, starlette, rich-click, reacton, ipyvue, ipyvuetify, solara-ui, solara-server, solara
# Successfully installed ipyvue-1.11.2 ipyvuetify-1.11.1 jedi-0.19.2 pymdown-extensions-10.14.3 reacton-1.9.1 rich-click-1.8.8 solara-1.44.1 solara-server-1.44.1 solara-ui-1.44.1 starlette-0.46.1 uvicorn-0.34.0 watchdog-6.0.0 watchfiles-1.0.4

# %%
# Mesa Sürümünü Doğrudan Sorgulama
# !pip show mesa
# Out:
# Name: Mesa
# Version: 3.1.5
# Summary: Agent-based modeling (ABM) in Python
# Home-page: https://github.com/projectmesa/mesa
# Author:
# Author-email: Project Mesa Team <projectmesa@googlegroups.com>
# License: Apache 2.0
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: numpy, pandas, scipy, tqdm
# Required-by:

# %%
# Python Üzerinden Sürüm Kontrolü
import mesa
mesa.__version__
# Out:
# '3.1.5'

# %%
# Tüm Yüklü Kütüphaneleri Listeleme
#!pip list

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
# Has multi-dimensional arrays and matrices.
# Has a large collection of mathematical functions to operate on these arrays.
import numpy as np

# Data manipulation and analysis.
import pandas as pd

# Data visualization tools.
import seaborn as sns

import mesa

# %%
import random
class MoneyAgent(mesa.Agent):
    """An agent with fixed initial wealth."""

    def __init__(self, model):
        # Pass the parameters to the parent class.
        super().__init__(model)


        # Create the agent's attribute and set the initial values.
        #self.nakit = 1000
        #self.hisse = 100

        # Özelliklere rastgele değer atama
        self.nakit = random.randint(1, 1000)  # 1-1000 arası rastgele servet
        self.hisse = random.randint(1, 100)     # 1-100 arası hisse

        # Alıcılar rastgele alış emri veriyor (fiyat: 90-110 arası, miktar: 1-10 arası)
        self.alis_fiyati = random.randint(90, 110)  # Piyasa fiyatı etrafında rastgele fiyat
        self.alis_miktari = random.randint(1, 10)  # Rastgele miktar



        self.alis_fiyat_carpı_miktar = self.alis_fiyati * self.alis_miktari
        self.alici_onceligi = ((self.alis_fiyati * 0.7) + (self.alis_miktari * 0.3))

        # Satıcılar rastgele satış emri veriyor (fiyat: 90-110 arası, miktar: 1-10 arası)
        self.satis_fiyati = random.randint(90, 110)  # Piyasa fiyatı etrafında rastgele fiyat
        self.satis_miktari = random.randint(1, 10)  # Rastgele miktar
        self.satis_fiyat_carpı_miktar = self.satis_fiyati * self.satis_miktari
        self.satici_onceligi = ((self.satis_fiyati * 0.7) + (self.satis_miktari * 0.3))





    def say_hi(self):
        # The agent's step will go here.
        # For demonstration purposes we will print the agent's unique_id
        print(f"\nHi, I am an agent, you can call me {self.unique_id!s}.")



class MoneyModel(mesa.Model):
    """A model with some number of agents."""

    def __init__(self, n, seed=None):
        super().__init__(seed=seed)
        self.num_agents = n


        # Create n agents
        # MoneyAgent.create_agents(model=self, n=n)

        self.agent_list_al = []  # Ajanları saklamak için boş liste
        self.agent_list_sat = []  # Ajanları saklamak için boş liste



        # MoneyAgent.create_agents() metodunun işlevini yerine getiren başka bir yöntemle oluşturma
          # yöntem 1:
        for _ in range(n):
            agent = MoneyAgent(self)  # next_id() gibi bir metotla benzersiz ID'ler atanabilir
            self.agents.add(agent)  # Ajanı schedule'a ekle (varsayılan olarak)
            # Al/sat listesi oluşturma
            if random.random() > 0.5:
                self.agent_list_al.append(agent)  # Ajanı al listeye ekle

                """print("alıcıyım ID numaram:", [agent.unique_id])
                print("alış için fiyat:", [agent.alis_fiyati])
                print("alış için mikar:", [agent.alis_miktari])
                print("+++++++++++++++++++++++++++++++++++++")"""

            else:
                self.agent_list_sat.append(agent)  # Ajanı sat listeye ekle

                """print("satıcıyım ID numaram:", [agent.unique_id])
                print("satış için fiyat:", [agent.satis_fiyati])
                print("satış için mikar:", [agent.satis_miktari])
                print("+++++++++++++++++++++++++++++++++++++")"""

##################################################################################################################################################################

        # 1. Toplam miktarları hesapla
        toplam_alis = 0
        for agent in self.agent_list_al:
            toplam_alis += agent.alis_miktari

        toplam_satis = 0
        for agent in self.agent_list_sat:
            toplam_satis += agent.satis_miktari

        print(f"Başlangıç Toplamları - Alış: {toplam_alis}, Satış: {toplam_satis}")

        # 2. Dengeleme işlemi
        if toplam_alis > toplam_satis:
            fazlalik = toplam_alis - toplam_satis
            print(f"Alış fazlası: {fazlalik} birim")

            # Alış fazlasını azaltma
            index = 0
            while fazlalik > 0 and self.agent_list_al:
                agent = self.agent_list_al[index % len(self.agent_list_al)]
                current = agent.alis_miktari

                if current > 0:
                    agent.alis_miktari = current - 1
                    fazlalik -= 1
                    print(f"Agent {agent.unique_id}: {current} -> {current-1} (Kalan fazlalık: {fazlalik})")

                index += 1

        elif toplam_satis > toplam_alis:
            fazlalik = toplam_satis - toplam_alis
            print(f"Satış fazlası: {fazlalik} birim")

            # Satış fazlasını azaltma
            index = 0
            while fazlalik > 0 and self.agent_list_sat:
                agent = self.agent_list_sat[index % len(self.agent_list_sat)]
                current = agent.satis_miktari

                if current > 0:
                    agent.satis_miktari = current - 1
                    fazlalik -= 1
                    print(f"Agent {agent.unique_id}: {current} -> {current-1} (Kalan fazlalık: {fazlalik})")

                index += 1

        else:
            print("Zaten dengeli!")



##################################################################################################################################################################




        # Ağırlıklı ortalama fiyat fonksiyonu
        # total_value / total_quantity

        alici_toplam_deger = sum(i.alis_fiyati * i.alis_miktari for i in self.agent_list_al)
        alici_toplam_miktar = sum(i.alis_miktari for i in self.agent_list_al)
        alici_agirlikli_ortalama = alici_toplam_deger / alici_toplam_miktar if alici_toplam_miktar != 0 else 0

        satici_toplam_deger = sum(j.satis_fiyati * j.satis_miktari for j in self.agent_list_sat)
        satici_toplam_miktar = sum(j.satis_miktari for j in self.agent_list_sat)
        satici_agirlikli_ortalama = satici_toplam_deger / satici_toplam_miktar if satici_toplam_miktar != 0 else 0

        agirlikli_ortalama = (alici_agirlikli_ortalama + satici_agirlikli_ortalama) / 2
        print("\nAğırlıklı Ortalama Fiyat:", agirlikli_ortalama)

        print("\nAlıcı Ajanların Emirleri:")
        for i in self.agent_list_al:
            print(f"ID: {i.unique_id}, Alış Fiyatı: {i.alis_fiyati}, Miktar: {i.alis_miktari}, Fiyat*Miktar: {i.alis_fiyat_carpı_miktar}, Fiyat*0,7+Miktar*0,3: {i.alici_onceligi}")
        print("\nSatıcı Ajanların Emirleri:")
        for j in self.agent_list_sat:
            print(f"ID: {j.unique_id}, Satış Fiyatı: {j.satis_fiyati}, Miktar: {j.satis_miktari}, Fiyat*Miktar: {j.satis_fiyat_carpı_miktar}, Fiyat*0,7+Miktar*0,3: {j.satici_onceligi}")

        # alıcıları büyükten küçüğe satıcıları küçükten büyüğe sırala
        sirali_alis = sorted(self.agent_list_al, key=lambda a: a.alici_onceligi, reverse=True)
        sirali_satis = sorted(self.agent_list_sat, key=lambda a: a.satici_onceligi)

        print("\nAlışa göre sıralama - büyükten küçüğe:")
        for agent in sirali_alis:
            print(f"Ajan {agent.unique_id}: {agent.alici_onceligi}")

        print("\nSatışa göre sıralama - küçükten büyüğe:")
        for agent in sirali_satis:
            print(f"Ajan {agent.unique_id}: {agent.satici_onceligi}")

        # Örnek: sirali_miktarlar daha önce sıralanmış liste
        sirali_miktarlar_alis = [agent.alis_miktari for agent in sirali_alis]
        print("\nsıralı miktarlar alış")
        print(sirali_miktarlar_alis)

        sirali_miktarlar_satis = [agent.satis_miktari for agent in sirali_satis]
        print("\nsıralı miktarlar satış")
        print(sirali_miktarlar_satis)


        len_alis = len(sirali_miktarlar_alis)
        len_satis = len(sirali_miktarlar_satis)

        if len_alis > len_satis:
            # Örnek: rastgele ama piyasa etrafında dalgalanan fiyatlar (örneğin 100 ± 3)
            piyasa_fiyat_listesi = [random.uniform(97, 103) for _ in sirali_miktarlar_alis]
            print("\nPiyasa Fiyatları:")
            print(piyasa_fiyat_listesi)
        elif len_satis > len_alis:
            piyasa_fiyat_listesi = [random.uniform(97, 103) for _ in sirali_miktarlar_satis]
            print("\nPiyasa Fiyatları:")
            print(piyasa_fiyat_listesi)
        else:
            print("İki listenin uzunluğu eşit.")


        # Her miktarı karşılık gelen fiyatla çarpalım
        carpim_sonuclari_alicilar = [m * f for m, f in zip(sirali_miktarlar_alis, piyasa_fiyat_listesi)]
        # Sonuçları yazdıralım: alış
        for i, (m, f, sonuc1) in enumerate(zip(sirali_miktarlar_alis, piyasa_fiyat_listesi, carpim_sonuclari_alicilar)):
            print(f"Miktar={m}, Fiyat={round(f,2)}, Çarpım={round(sonuc1,2)}")

        carpim_sonuclari_saticilar = [a * b for a, b in zip(sirali_miktarlar_satis, piyasa_fiyat_listesi)]
        # Sonuçları yazdıralım: satış
        for i, (a, b, sonuc2) in enumerate(zip(sirali_miktarlar_satis, piyasa_fiyat_listesi, carpim_sonuclari_saticilar)):
            print(f"Miktar={a}, Fiyat={round(b,2)}, Çarpım={round(sonuc2,2)}")



###########################################################################################################################################################



##################################################################################################################################################################


##################################################################################################################################################################
        # Alıcıları alış_fiyati'na göre büyükten küçüğe sırala / NOT: BURADAKİ GİBİ ALIŞ FİYATINA GÖRE DEĞİL ALIŞ FİYATI*ALIŞ MİKTARI NA GÖRE SIRALAMA YAPILMALI
        agent_list_al_sirali = sorted(
            self.agent_list_al,
            key=lambda agent: agent.alis_fiyati,
            reverse=True
        )
        # Kontrol çıktısı
        print("\nAlıcılar (Yüksek → Düşük Fiyat):")
        for agent in agent_list_al_sirali:
            print(f"ID: {agent.unique_id}, Fiyat: {agent.alis_fiyati}, Miktar: {agent.alis_miktari}")




        # Satıcıların satıs_fiyatına'na göre büyükten küçüğe sırala
        agent_list_sat_sirali = sorted(
            self.agent_list_sat,
            key=lambda agent: agent.satis_fiyati,
            reverse=True
        )
        # Kontrol çıktısı
        print("\nSatıcıların (yüksek → düşük):")
        for agent in agent_list_sat_sirali:
            print(f"ID: {agent.unique_id}, Fiyat: {agent.satis_fiyati}, Miktar: {agent.satis_miktari}")


        # Alıcıların fiyat*miktar'na göre büyükten küçüğe sırala
        agent_list_al_sirali_fiyat_carpi_miktar = sorted(
            self.agent_list_al,
            key=lambda agent: agent.alis_fiyat_carpı_miktar,
            reverse=True
        )
        # Kontrol çıktısı
        print("\nAlıcıların fiyat*miktar (yüksek → düşük):")
        for agent in agent_list_al_sirali_fiyat_carpi_miktar:
            print(f"ID: {agent.unique_id}, Fiyat: {agent.alis_fiyati}, Miktar: {agent.alis_miktari}, Fiyat*Miktar: {agent.alis_fiyat_carpı_miktar}")



        # Satıcıların fiyat*miktar'na göre büyükten küçüğe sırala
        agent_list_sat_sirali_fiyat_carpi_miktar = sorted(
            self.agent_list_sat,
            key=lambda agent: agent.satis_fiyat_carpı_miktar,
            reverse=True
        )
        # Kontrol çıktısı
        print("\nSatıcıların fiyat*miktar (yüksek → düşük):")
        for agent in agent_list_sat_sirali_fiyat_carpi_miktar:
            print(f"ID: {agent.unique_id}, Fiyat: {agent.satis_fiyati}, Miktar: {agent.satis_miktari}, Fiyat*Miktar: {agent.satis_fiyat_carpı_miktar}")

########################################################################################################################################
        """# Alıcıları alici_onceligi'ne göre büyükten küçüğe sırala

        # Orijinal listeyi koruyarak kopyalama
        orijinal_liste1 = self.agent_list_al.copy()

        # Önceliğe göre sıralama
        self.agent_list_al.sort(key=lambda x: x.alici_onceligi, reverse=True)

        # Sıralanmış liste üzerinde miktarlara erişim
        print("\nAlcıların önceliğini sıralama:")
        for i, agent in enumerate(self.agent_list_al):

            print(f"Sıra {i+1}: ID {agent.unique_id} - Fiyat: {agent.alis_fiyati}- Miktar: {agent.alis_miktari} - Öncelik: {agent.alici_onceligi:.2f}")


        # Orijinal listeyi koruyarak kopyalama
        orijinal_liste2 = self.agent_list_sat.copy()

        # Önceliğe göre sıralama
        self.agent_list_sat.sort(key=lambda x: x.satici_onceligi)

        # Sıralanmış liste üzerinde miktarlara erişim
        print("\nSatıcıların önceliğini sıralama:")
        for i, agent in enumerate(self.agent_list_sat):

            print(f"Sıra {i+1}: ID {agent.unique_id} - Fiyat: {agent.satis_fiyati}- Miktar: {agent.satis_miktari} - Öncelik: {agent.satici_onceligi:.2f}")"""




########################################################################################################################################

        self.sayac = 0
    def step(self):
        """Advance the model by one step."""
        # This function psuedo-randomly reorders the list of agent objects and
        # then iterates through calling the function passed in as the parameter
        self.agents.shuffle_do("say_hi")
        self.sayac = self.sayac + 1
        print(self.sayac)

# %%
model = MoneyModel(10)  # Tells the model to create 10 agents
for _ in range(1):  # Runs the model for 30 steps;
    model.step()
# Out:
# Başlangıç Toplamları - Alış: 17, Satış: 31
# Satış fazlası: 14 birim
# Agent 1: 6 -> 5 (Kalan fazlalık: 13)
# Agent 2: 7 -> 6 (Kalan fazlalık: 12)
# Agent 4: 6 -> 5 (Kalan fazlalık: 11)
# Agent 7: 4 -> 3 (Kalan fazlalık: 10)
# Agent 8: 1 -> 0 (Kalan fazlalık: 9)
# Agent 9: 3 -> 2 (Kalan fazlalık: 8)
# Agent 10: 4 -> 3 (Kalan fazlalık: 7)
# Agent 1: 5 -> 4 (Kalan fazlalık: 6)
# Agent 2: 6 -> 5 (Kalan fazlalık: 5)
# Agent 4: 5 -> 4 (Kalan fazlalık: 4)
# Agent 7: 3 -> 2 (Kalan fazlalık: 3)
# Agent 9: 2 -> 1 (Kalan fazlalık: 2)
# Agent 10: 3 -> 2 (Kalan fazlalık: 1)
# Agent 1: 4 -> 3 (Kalan fazlalık: 0)
#
# Ağırlıklı Ortalama Fiyat: 99.67647058823529
#
# Alıcı Ajanların Emirleri:
# ID: 3, Alış Fiyatı: 104, Miktar: 8, Fiyat*Miktar: 832, Fiyat*0,7+Miktar*0,3: 75.2
# ID: 5, Alış Fiyatı: 100, Miktar: 2, Fiyat*Miktar: 200, Fiyat*0,7+Miktar*0,3: 70.6
# ID: 6, Alış Fiyatı: 94, Miktar: 7, Fiyat*Miktar: 658, Fiyat*0,7+Miktar*0,3: 67.89999999999999
#
# Satıcı Ajanların Emirleri:
# ID: 1, Satış Fiyatı: 103, Miktar: 3, Fiyat*Miktar: 618, Fiyat*0,7+Miktar*0,3: 73.89999999999999
# ID: 2, Satış Fiyatı: 100, Miktar: 5, Fiyat*Miktar: 700, Fiyat*0,7+Miktar*0,3: 72.1
# ID: 4, Satış Fiyatı: 101, Miktar: 4, Fiyat*Miktar: 606, Fiyat*0,7+Miktar*0,3: 72.49999999999999
# ID: 7, Satış Fiyatı: 102, Miktar: 2, Fiyat*Miktar: 408, Fiyat*0,7+Miktar*0,3: 72.6
# ID: 8, Satış Fiyatı: 110, Miktar: 0, Fiyat*Miktar: 110, Fiyat*0,7+Miktar*0,3: 77.3
# ID: 9, Satış Fiyatı: 98, Miktar: 1, Fiyat*Miktar: 294, Fiyat*0,7+Miktar*0,3: 69.5
# ID: 10, Satış Fiyatı: 92, Miktar: 2, Fiyat*Miktar: 368, Fiyat*0,7+Miktar*0,3: 65.6
#
# Alışa göre sıralama - büyükten küçüğe:
# Ajan 3: 75.2
# Ajan 5: 70.6
# Ajan 6: 67.89999999999999
#
# Satışa göre sıralama - küçükten büyüğe:
# Ajan 10: 65.6
# Ajan 9: 69.5
# Ajan 2: 72.1
# Ajan 4: 72.49999999999999
# Ajan 7: 72.6
# Ajan 1: 73.89999999999999
# Ajan 8: 77.3
#
# sıralı miktarlar alış
# [8, 2, 7]
#
# sıralı miktarlar satış
# [2, 1, 5, 4, 2, 3, 0]
#
# Piyasa Fiyatları:
# [100.27080542957258, 101.95199914622195, 98.05232021728152, 100.47585005320393, 100.83454950012515, 102.0502184820673, 98.74387908501046]
# Miktar=8, Fiyat=100.27, Çarpım=802.17
# Miktar=2, Fiyat=101.95, Çarpım=203.9
# Miktar=7, Fiyat=98.05, Çarpım=686.37
# Miktar=2, Fiyat=100.27, Çarpım=200.54
# Miktar=1, Fiyat=101.95, Çarpım=101.95
# Miktar=5, Fiyat=98.05, Çarpım=490.26
# Miktar=4, Fiyat=100.48, Çarpım=401.9
# Miktar=2, Fiyat=100.83, Çarpım=201.67
# Miktar=3, Fiyat=102.05, Çarpım=306.15
# Miktar=0, Fiyat=98.74, Çarpım=0.0
#
# Alıcılar (Yüksek → Düşük Fiyat):
# ID: 3, Fiyat: 104, Miktar: 8
# ID: 5, Fiyat: 100, Miktar: 2
# ID: 6, Fiyat: 94, Miktar: 7
#
# Satıcıların (yüksek → düşük):
# ID: 8, Fiyat: 110, Miktar: 0
# ID: 1, Fiyat: 103, Miktar: 3
# ID: 7, Fiyat: 102, Miktar: 2
# ID: 4, Fiyat: 101, Miktar: 4
# ID: 2, Fiyat: 100, Miktar: 5
# ID: 9, Fiyat: 98, Miktar: 1
# ID: 10, Fiyat: 92, Miktar: 2
#
# Alıcıların fiyat*miktar (yüksek → düşük):
# ID: 3, Fiyat: 104, Miktar: 8, Fiyat*Miktar: 832
# ID: 6, Fiyat: 94, Miktar: 7, Fiyat*Miktar: 658
# ID: 5, Fiyat: 100, Miktar: 2, Fiyat*Miktar: 200
#
# Satıcıların fiyat*miktar (yüksek → düşük):
# ID: 2, Fiyat: 100, Miktar: 5, Fiyat*Miktar: 700
# ID: 1, Fiyat: 103, Miktar: 3, Fiyat*Miktar: 618
# ID: 4, Fiyat: 101, Miktar: 4, Fiyat*Miktar: 606
# ID: 7, Fiyat: 102, Miktar: 2, Fiyat*Miktar: 408
# ID: 10, Fiyat: 92, Miktar: 2, Fiyat*Miktar: 368
# ID: 9, Fiyat: 98, Miktar: 1, Fiyat*Miktar: 294
# ID: 8, Fiyat: 110, Miktar: 0, Fiyat*Miktar: 110
#
# Hi, I am an agent, you can call me 7.
#
# Hi, I am an agent, you can call me 1.
#
# Hi, I am an agent, you can call me 4.
#
# Hi, I am an agent, you can call me 6.
#
# Hi, I am an agent, you can call me 5.
#
# Hi, I am an agent, you can call me 3.
#
# Hi, I am an agent, you can call me 8.
#
# Hi, I am an agent, you can call me 2.
#
# Hi, I am an agent, you can call me 10.
#
# Hi, I am an agent, you can call me 9.
# 1
